# %% [markdown]
# <a href="https://colab.research.google.com/github/OUCTheoryGroup/colab_demo/blob/master/DSCMR_CVPR2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DSCMR 深度监督跨模态检索
#
# Liangli Zhen, Peng Hu, Xu Wang, Dezhong Peng, Deep Supervised Cross-modal Retrieval. *CVPR 2029*

# %%
! mkdir pascal
! wget -P pascal https://raw.githubusercontent.com/penghu-cs/DSCMR/master/data/pascal/test_img.mat
! wget -P pascal https://raw.githubusercontent.com/penghu-cs/DSCMR/master/data/pascal/test_img_lab.mat
! wget -P pascal https://raw.githubusercontent.com/penghu-cs/DSCMR/master/data/pascal/test_txt.mat
! wget -P pascal https://raw.githubusercontent.com/penghu-cs/DSCMR/master/data/pascal/train_img.mat
! wget -P pascal https://raw.githubusercontent.com/penghu-cs/DSCMR/master/data/pascal/train_img_lab.mat
! wget -P pascal https://raw.githubusercontent.com/penghu-cs/DSCMR/master/data/pascal/train_txt.mat

# %%
import torch
from datetime import datetime
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data.dataset import Dataset
from scipy.io import loadmat, savemat
from torch.utils.data import DataLoader
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
import time
import copy
import scipy.spatial

# %%
class ImgNN(nn.Module):
    """Network to learn image representations"""
    def __init__(self, input_dim=4096, output_dim=1024):
        super(ImgNN, self).__init__()
        self.denseL1 = nn.Linear(input_dim, output_dim)
        
    def forward(self, x):
        out = F.relu(self.denseL1(x))
        return out

class TextNN(nn.Module):
    """Network to learn text representations"""
    def __init__(self, input_dim=1024, output_dim=1024):
        super(TextNN, self).__init__()
        self.denseL1 = nn.Linear(input_dim, output_dim)

    def forward(self, x):
        out = F.relu(self.denseL1(x))
        return out

# %%
class IDCM_NN(nn.Module):
    """Network to learn text representations"""
    def __init__(self, img_input_dim=4096, img_output_dim=2048,
                 text_input_dim=1024, text_output_dim=2048, minus_one_dim=1024, output_dim=10):
        super(IDCM_NN, self).__init__()
        self.img_net = ImgNN(img_input_dim, img_output_dim)
        self.text_net = TextNN(text_input_dim, text_output_dim)
        self.linearLayer = nn.Linear(img_output_dim, minus_one_dim)
        self.linearLayer2 = nn.Linear(minus_one_dim, output_dim)

    def forward(self, img, text):
        view1_feature = self.img_net(img)
        view2_feature = self.text_net(text)
        view1_feature = self.linearLayer(view1_feature)
        view2_feature = self.linearLayer(view2_feature)

        view1_predict = self.linearLayer2(view1_feature)
        view2_predict = self.linearLayer2(view2_feature)
        return view1_feature, view2_feature, view1_predict, view2_predict

# %%
class CustomDataSet(Dataset):
    def __init__(
            self,
            images,
            texts,
            labels):
        self.images = images
        self.texts = texts
        self.labels = labels

    def __getitem__(self, index):
        img = self.images[index]
        text = self.texts[index]
        label = self.labels[index]
        return img, text, label

    def __len__(self):
        count = len(self.images)
        assert len(
            self.images) == len(self.labels)
        return count

def ind2vec(ind, N=None):
    ind = np.asarray(ind)
    if N is None:
        N = ind.max() + 1
    return np.arange(N) == np.repeat(ind, N, axis=1)

def get_loader(path, batch_size):
    img_train = loadmat(path+"train_img.mat")['train_img']
    img_test = loadmat(path + "test_img.mat")['test_img']
    text_train = loadmat(path+"train_txt.mat")['train_txt']
    text_test = loadmat(path + "test_txt.mat")['test_txt']
    label_train = loadmat(path+"train_img_lab.mat")['train_img_lab']
    label_test = loadmat(path + "test_img_lab.mat")['test_img_lab']

    label_train = ind2vec(label_train).astype(int)
    label_test = ind2vec(label_test).astype(int)

    imgs = {'train': img_train, 'test': img_test}
    texts = {'train': text_train, 'test': text_test}
    labels = {'train': label_train, 'test': label_test}
    dataset = {x: CustomDataSet(images=imgs[x], texts=texts[x], labels=labels[x])
               for x in ['train', 'test']}

    shuffle = {'train': False, 'test': False}

    dataloader = {x: DataLoader(dataset[x], batch_size=batch_size,
                                shuffle=shuffle[x], num_workers=0) for x in ['train', 'test']}

    img_dim = img_train.shape[1]
    text_dim = text_train.shape[1]
    num_class = label_train.shape[1]

    input_data_par = {}
    input_data_par['img_test'] = img_test
    input_data_par['text_test'] = text_test
    input_data_par['label_test'] = label_test
    input_data_par['img_train'] = img_train
    input_data_par['text_train'] = text_train
    input_data_par['label_train'] = label_train
    input_data_par['img_dim'] = img_dim
    input_data_par['text_dim'] = text_dim
    input_data_par['num_class'] = num_class
    return dataloader, input_data_par

# %%
def train_model(model, data_loaders, optimizer, alpha, beta, device="cpu", num_epochs=500):
    since = time.time()
    # device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_img_acc_history = []
    test_txt_acc_history = []
    epoch_loss_history =[]

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 20)

        # Each epoch has a training and validation phase
        for phase in ['train', 'test']:
            if phase == 'train':
                # Set model to training mode
                model.train()
            else:
                # Set model to evaluate mode
                model.eval()

            running_loss = 0.0
            running_corrects_img = 0
            running_corrects_txt = 0
            # Iterate over data.
            for imgs, txts, labels in data_loaders[phase]:
                # imgs = imgs.to(device)
                # txts = txts.to(device)
                # labels = labels.to(device)
                if torch.sum(imgs != imgs)>1 or torch.sum(txts != txts)>1:
                    print("Data contains Nan.")

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    # Special case for inception because in training it has an auxiliary output. In train
                    #   mode we calculate the loss by summing the final output and the auxiliary output
                    #   but in testing we only consider the final output.
                    if torch.cuda.is_available():
                        imgs = imgs.cuda()
                        txts = txts.cuda()
                        labels = labels.cuda()


                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # Forward
                    view1_feature, view2_feature, view1_predict, view2_predict = model(imgs, txts)

                    loss = calc_loss(view1_feature, view2_feature, view1_predict,
                                     view2_predict, labels, labels, alpha, beta)

                    img_preds = view1_predict
                    txt_preds = view2_predict

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item()
                running_corrects_img += torch.sum(torch.argmax(img_preds, dim=1) == torch.argmax(labels, dim=1))
                running_corrects_txt += torch.sum(torch.argmax(txt_preds, dim=1) == torch.argmax(labels, dim=1))

            epoch_loss = running_loss / len(data_loaders[phase].dataset)
            # epoch_img_acc = running_corrects_img.double() / len(data_loaders[phase].dataset)
            # epoch_txt_acc = running_corrects_txt.double() / len(data_loaders[phase].dataset)
            t_imgs, t_txts, t_labels = [], [], []
            with torch.no_grad():
                for imgs, txts, labels in data_loaders['test']:
                    if torch.cuda.is_available():
                            imgs = imgs.cuda()
                            txts = txts.cuda()
                            labels = labels.cuda()
                    t_view1_feature, t_view2_feature, _, _ = model(imgs, txts)
                    t_imgs.append(t_view1_feature.cpu().numpy())
                    t_txts.append(t_view2_feature.cpu().numpy())
                    t_labels.append(labels.cpu().numpy())
            t_imgs = np.concatenate(t_imgs)
            t_txts = np.concatenate(t_txts)
            t_labels = np.concatenate(t_labels).argmax(1)
            img2text = fx_calc_map_label(t_imgs, t_txts, t_labels)
            txt2img = fx_calc_map_label(t_txts, t_imgs, t_labels)

            print('{} Loss: {:.4f} Img2Txt: {:.4f}  Txt2Img: {:.4f}'.format(phase, epoch_loss, img2text, txt2img))

            # deep copy the model
            if phase == 'test' and (img2text + txt2img) / 2. > best_acc:
                best_acc = (img2text + txt2img) / 2.
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'test':
                test_img_acc_history.append(img2text)
                test_txt_acc_history.append(txt2img)
                epoch_loss_history.append(epoch_loss)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best average ACC: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, test_img_acc_history, test_txt_acc_history, epoch_loss_history

# %%
def calc_loss(view1_feature, view2_feature, view1_predict, view2_predict, labels_1, labels_2, alpha, beta):
    term1 = ((view1_predict-labels_1.float())**2).sum(1).sqrt().mean() + ((view2_predict-labels_2.float())**2).sum(1).sqrt().mean()

    cos = lambda x, y: x.mm(y.t()) / ((x ** 2).sum(1, keepdim=True).sqrt().mm((y ** 2).sum(1, keepdim=True).sqrt().t())).clamp(min=1e-6) / 2.
    theta11 = cos(view1_feature, view1_feature)
    theta12 = cos(view1_feature, view2_feature)
    theta22 = cos(view2_feature, view2_feature)
    Sim11 = calc_label_sim(labels_1, labels_1).float()
    Sim12 = calc_label_sim(labels_1, labels_2).float()
    Sim22 = calc_label_sim(labels_2, labels_2).float()
    term21 = ((1+torch.exp(theta11)).log() - Sim11 * theta11).mean()
    term22 = ((1+torch.exp(theta12)).log() - Sim12 * theta12).mean()
    term23 = ((1 + torch.exp(theta22)).log() - Sim22 * theta22).mean()
    term2 = term21 + term22 + term23

    term3 = ((view1_feature - view2_feature)**2).sum(1).sqrt().mean()

    im_loss = term1 + alpha * term2 + beta * term3
    return im_loss

def calc_label_sim(label_1, label_2):
    Sim = label_1.float().mm(label_2.float().t())
    return Sim

# %%
def fx_calc_map_label(image, text, label, k = 0, dist_method='COS'):
  if dist_method == 'L2':
    dist = scipy.spatial.distance.cdist(image, text, 'euclidean')
  elif dist_method == 'COS':
    dist = scipy.spatial.distance.cdist(image, text, 'cosine')
  ord = dist.argsort()
  numcases = dist.shape[0]
  if k == 0:
    k = numcases
  res = []
  for i in range(numcases):
    order = ord[i]
    p = 0.0
    r = 0.0
    for j in range(k):
      if label[i] == label[order[j]]:
        r += 1
        p += (r / (j + 1))
    if r > 0:
      res += [p / r]
    else:
      res += [0]
  return np.mean(res)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# data parameters
DATA_DIR = 'pascal/'
alpha = 1e-3
beta = 1e-1
MAX_EPOCH = 200
batch_size = 100
# batch_size = 512
lr = 1e-4
betas = (0.5, 0.999)
weight_decay = 0

print('...Data loading is beginning...')

data_loader, input_data_par = get_loader(DATA_DIR, batch_size)

print('...Data loading is completed...')

model_ft = IDCM_NN(img_input_dim=input_data_par['img_dim'], text_input_dim=input_data_par['text_dim'], output_dim=input_data_par['num_class']).to(device)
params_to_update = list(model_ft.parameters())

# Observe that all parameters are being optimized
optimizer = optim.Adam(params_to_update, lr=lr, betas=betas)

print('...Training is beginning...')
# Train and evaluate
model_ft, img_acc_hist, txt_acc_hist, loss_hist = train_model(model_ft, data_loader, optimizer, alpha, beta, MAX_EPOCH)
print('...Training is completed...')

print('...Evaluation on testing data...')
view1_feature, view2_feature, view1_predict, view2_predict = model_ft(torch.tensor(input_data_par['img_test']).to(device), torch.tensor(input_data_par['text_test']).to(device))
label = torch.argmax(torch.tensor(input_data_par['label_test']), dim=1)
view1_feature = view1_feature.detach().cpu().numpy()
view2_feature = view2_feature.detach().cpu().numpy()
view1_predict = view1_predict.detach().cpu().numpy()
view2_predict = view2_predict.detach().cpu().numpy()
img_to_txt = fx_calc_map_label(view1_feature, view2_feature, label)
print('...Image to Text MAP = {}'.format(img_to_txt))

txt_to_img = fx_calc_map_label(view2_feature, view1_feature, label)
print('...Text to Image MAP = {}'.format(txt_to_img))

print('...Average MAP = {}'.format(((img_to_txt + txt_to_img) / 2.)))
# Out:
# ...Data loading is beginning...
# ...Data loading is completed...
# ...Training is beginning...
# Epoch 1/500
# --------------------
# train Loss: 0.0267 Img2Txt: 0.2081  Txt2Img: 0.2477
# test Loss: 0.0229 Img2Txt: 0.2081  Txt2Img: 0.2477
#
# Epoch 2/500
# --------------------
# train Loss: 0.0228 Img2Txt: 0.4067  Txt2Img: 0.4179
# test Loss: 0.0204 Img2Txt: 0.4067  Txt2Img: 0.4179
#
# Epoch 3/500
# --------------------
# train Loss: 0.0207 Img2Txt: 0.5217  Txt2Img: 0.5267
# test Loss: 0.0187 Img2Txt: 0.5217  Txt2Img: 0.5267
#
# Epoch 4/500
# --------------------
# train Loss: 0.0187 Img2Txt: 0.5594  Txt2Img: 0.5960
# test Loss: 0.0174 Img2Txt: 0.5594  Txt2Img: 0.5960
#
# Epoch 5/500
# --------------------
# train Loss: 0.0170 Img2Txt: 0.5938  Txt2Img: 0.6371
# test Loss: 0.0165 Img2Txt: 0.5938  Txt2Img: 0.6371
#
# Epoch 6/500
# --------------------
# train Loss: 0.0156 Img2Txt: 0.6224  Txt2Img: 0.6591
# test Loss: 0.0158 Img2Txt: 0.6224  Txt2Img: 0.6591
#
# Epoch 7/500
# --------------------
# train Loss: 0.0146 Img2Txt: 0.6271  Txt2Img: 0.6685
# test Loss: 0.0155 Img2Txt: 0.6271  Txt2Img: 0.6685
#
# Epoch 8/500
# --------------------
# train Loss: 0.0140 Img2Txt: 0.6461  Txt2Img: 0.6762
# test Loss: 0.0153 Img2Txt: 0.6461  Txt2Img: 0.6762
#
# Epoch 9/500
# --------------------
# train Loss: 0.0136 Img2Txt: 0.6570  Txt2Img: 0.6914
# test Loss: 0.0152 Img2Txt: 0.6570  Txt2Img: 0.6914
#
# Epoch 10/500
# --------------------
# train Loss: 0.0132 Img2Txt: 0.6597  Txt2Img: 0.6969
# test Loss: 0.0151 Img2Txt: 0.6597  Txt2Img: 0.6969
#
# Epoch 11/500
# --------------------
# train Loss: 0.0129 Img2Txt: 0.6583  Txt2Img: 0.7032
# test Loss: 0.0149 Img2Txt: 0.6583  Txt2Img: 0.7032
#
# Epoch 12/500
# --------------------
# train Loss: 0.0127 Img2Txt: 0.6686  Txt2Img: 0.7086
# test Loss: 0.0150 Img2Txt: 0.6686  Txt2Img: 0.7086
#
# Epoch 13/500
# --------------------
# train Loss: 0.0122 Img2Txt: 0.6693  Txt2Img: 0.7114
# test Loss: 0.0149 Img2Txt: 0.6693  Txt2Img: 0.7114
#
# Epoch 14/500
# --------------------
# train Loss: 0.0122 Img2Txt: 0.6628  Txt2Img: 0.7001
# test Loss: 0.0147 Img2Txt: 0.6628  Txt2Img: 0.7001
#
# Epoch 15/500
# --------------------
# train Loss: 0.0115 Img2Txt: 0.6705  Txt2Img: 0.7034
# test Loss: 0.0147 Img2Txt: 0.6705  Txt2Img: 0.7034
#
# Epoch 16/500
# --------------------
# train Loss: 0.0115 Img2Txt: 0.6731  Txt2Img: 0.7106
# test Loss: 0.0145 Img2Txt: 0.6731  Txt2Img: 0.7106
#
# Epoch 17/500
# --------------------
# train Loss: 0.0113 Img2Txt: 0.6743  Txt2Img: 0.7111
# test Loss: 0.0143 Img2Txt: 0.6743  Txt2Img: 0.7111
#
# Epoch 18/500
# --------------------
# train Loss: 0.0112 Img2Txt: 0.6703  Txt2Img: 0.7110
# test Loss: 0.0146 Img2Txt: 0.6703  Txt2Img: 0.7110
#
# Epoch 19/500
# --------------------
# train Loss: 0.0110 Img2Txt: 0.6691  Txt2Img: 0.7066
# test Loss: 0.0145 Img2Txt: 0.6691  Txt2Img: 0.7066
#
# Epoch 20/500
# --------------------
# train Loss: 0.0108 Img2Txt: 0.6630  Txt2Img: 0.7051
# test Loss: 0.0145 Img2Txt: 0.6630  Txt2Img: 0.7051
#
# Epoch 21/500
# --------------------
# train Loss: 0.0105 Img2Txt: 0.6805  Txt2Img: 0.7078
# test Loss: 0.0144 Img2Txt: 0.6805  Txt2Img: 0.7078
#
# Epoch 22/500
# --------------------
# train Loss: 0.0104 Img2Txt: 0.6785  Txt2Img: 0.7021
# test Loss: 0.0141 Img2Txt: 0.6785  Txt2Img: 0.7021
#
# Epoch 23/500
# --------------------
# train Loss: 0.0102 Img2Txt: 0.6947  Txt2Img: 0.7100
# test Loss: 0.0141 Img2Txt: 0.6947  Txt2Img: 0.7100
#
# Epoch 24/500
# --------------------
# train Loss: 0.0100 Img2Txt: 0.6649  Txt2Img: 0.6981
# test Loss: 0.0140 Img2Txt: 0.6649  Txt2Img: 0.6981
#
# Epoch 25/500
# --------------------
# train Loss: 0.0099 Img2Txt: 0.6690  Txt2Img: 0.7083
# test Loss: 0.0142 Img2Txt: 0.6690  Txt2Img: 0.7083
#
# Epoch 26/500
# --------------------
# train Loss: 0.0098 Img2Txt: 0.6654  Txt2Img: 0.6994
# test Loss: 0.0142 Img2Txt: 0.6654  Txt2Img: 0.6994
#
# Epoch 27/500
# --------------------
# train Loss: 0.0096 Img2Txt: 0.6643  Txt2Img: 0.6990
# test Loss: 0.0138 Img2Txt: 0.6643  Txt2Img: 0.6990
#
# Epoch 28/500
# --------------------
# train Loss: 0.0095 Img2Txt: 0.6888  Txt2Img: 0.7041
# test Loss: 0.0138 Img2Txt: 0.6888  Txt2Img: 0.7041
#
# Epoch 29/500
# --------------------
# train Loss: 0.0093 Img2Txt: 0.6700  Txt2Img: 0.7053
# test Loss: 0.0136 Img2Txt: 0.6700  Txt2Img: 0.7053
#
# Epoch 30/500
# --------------------
# train Loss: 0.0092 Img2Txt: 0.6714  Txt2Img: 0.7076
# test Loss: 0.0139 Img2Txt: 0.6714  Txt2Img: 0.7076
#
# Epoch 31/500
# --------------------
# train Loss: 0.0092 Img2Txt: 0.6674  Txt2Img: 0.7046
# test Loss: 0.0139 Img2Txt: 0.6674  Txt2Img: 0.7046
#
# Epoch 32/500
# --------------------
# train Loss: 0.0091 Img2Txt: 0.6472  Txt2Img: 0.6954
# test Loss: 0.0137 Img2Txt: 0.6472  Txt2Img: 0.6954
#
# Epoch 33/500
# --------------------
# train Loss: 0.0086 Img2Txt: 0.6878  Txt2Img: 0.6993
# test Loss: 0.0137 Img2Txt: 0.6878  Txt2Img: 0.6993
#
# Epoch 34/500
# --------------------
# train Loss: 0.0087 Img2Txt: 0.6543  Txt2Img: 0.6975
# test Loss: 0.0135 Img2Txt: 0.6543  Txt2Img: 0.6975
#
# Epoch 35/500
# --------------------
# train Loss: 0.0088 Img2Txt: 0.6737  Txt2Img: 0.6990
# test Loss: 0.0136 Img2Txt: 0.6737  Txt2Img: 0.6990
#
# Epoch 36/500
# --------------------
# train Loss: 0.0086 Img2Txt: 0.6552  Txt2Img: 0.6899
# test Loss: 0.0138 Img2Txt: 0.6552  Txt2Img: 0.6899
#
# Epoch 37/500
# --------------------
# train Loss: 0.0084 Img2Txt: 0.6593  Txt2Img: 0.6958
# test Loss: 0.0137 Img2Txt: 0.6593  Txt2Img: 0.6958
#
# Epoch 38/500
# --------------------
# train Loss: 0.0084 Img2Txt: 0.6394  Txt2Img: 0.6928
# test Loss: 0.0135 Img2Txt: 0.6394  Txt2Img: 0.6928
#
# Epoch 39/500
# --------------------
# train Loss: 0.0083 Img2Txt: 0.6828  Txt2Img: 0.6968
# test Loss: 0.0134 Img2Txt: 0.6828  Txt2Img: 0.6968
#
# Epoch 40/500
# --------------------
# train Loss: 0.0085 Img2Txt: 0.6639  Txt2Img: 0.6946
# test Loss: 0.0137 Img2Txt: 0.6639  Txt2Img: 0.6946
#
# Epoch 41/500
# --------------------
# train Loss: 0.0084 Img2Txt: 0.6677  Txt2Img: 0.6892
# test Loss: 0.0133 Img2Txt: 0.6677  Txt2Img: 0.6892
#
# Epoch 42/500
# --------------------
# train Loss: 0.0078 Img2Txt: 0.6612  Txt2Img: 0.6858
# test Loss: 0.0137 Img2Txt: 0.6612  Txt2Img: 0.6858
#
# Epoch 43/500
# --------------------
# train Loss: 0.0084 Img2Txt: 0.6698  Txt2Img: 0.6941
# test Loss: 0.0134 Img2Txt: 0.6698  Txt2Img: 0.6941
#
# Epoch 44/500
# --------------------
# train Loss: 0.0078 Img2Txt: 0.6708  Txt2Img: 0.6920
# test Loss: 0.0135 Img2Txt: 0.6708  Txt2Img: 0.6920
#
# Epoch 45/500
# --------------------
# train Loss: 0.0085 Img2Txt: 0.6421  Txt2Img: 0.6789
# test Loss: 0.0136 Img2Txt: 0.6421  Txt2Img: 0.6789
#
# Epoch 46/500
# --------------------
# train Loss: 0.0081 Img2Txt: 0.6530  Txt2Img: 0.6937
# test Loss: 0.0136 Img2Txt: 0.6530  Txt2Img: 0.6937
#
# Epoch 47/500
# --------------------
# train Loss: 0.0081 Img2Txt: 0.6705  Txt2Img: 0.7004
# test Loss: 0.0135 Img2Txt: 0.6705  Txt2Img: 0.7004
#
# Epoch 48/500
# --------------------
# train Loss: 0.0079 Img2Txt: 0.6713  Txt2Img: 0.6864
# test Loss: 0.0135 Img2Txt: 0.6713  Txt2Img: 0.6864
#
# Epoch 49/500
# --------------------
# train Loss: 0.0080 Img2Txt: 0.6698  Txt2Img: 0.6930
# test Loss: 0.0131 Img2Txt: 0.6698  Txt2Img: 0.6930
#
# Epoch 50/500
# --------------------
# train Loss: 0.0075 Img2Txt: 0.6656  Txt2Img: 0.6937
# test Loss: 0.0136 Img2Txt: 0.6656  Txt2Img: 0.6937
#
# Epoch 51/500
# --------------------
# train Loss: 0.0078 Img2Txt: 0.6594  Txt2Img: 0.6791
# test Loss: 0.0134 Img2Txt: 0.6594  Txt2Img: 0.6791
#
# Epoch 52/500
# --------------------
# train Loss: 0.0076 Img2Txt: 0.6638  Txt2Img: 0.6910
# test Loss: 0.0133 Img2Txt: 0.6638  Txt2Img: 0.6910
#
# Epoch 53/500
# --------------------
# train Loss: 0.0075 Img2Txt: 0.6566  Txt2Img: 0.6831
# test Loss: 0.0134 Img2Txt: 0.6566  Txt2Img: 0.6831
#
# Epoch 54/500
# --------------------
# train Loss: 0.0078 Img2Txt: 0.6731  Txt2Img: 0.6931
# test Loss: 0.0134 Img2Txt: 0.6731  Txt2Img: 0.6931
#
# Epoch 55/500
# --------------------
# train Loss: 0.0077 Img2Txt: 0.6318  Txt2Img: 0.6714
# test Loss: 0.0134 Img2Txt: 0.6318  Txt2Img: 0.6714
#
# Epoch 56/500
# --------------------
# train Loss: 0.0075 Img2Txt: 0.6737  Txt2Img: 0.6997
# test Loss: 0.0134 Img2Txt: 0.6737  Txt2Img: 0.6997
#
# Epoch 57/500
# --------------------
# train Loss: 0.0075 Img2Txt: 0.6535  Txt2Img: 0.6814
# test Loss: 0.0131 Img2Txt: 0.6535  Txt2Img: 0.6814
#
# Epoch 58/500
# --------------------
# train Loss: 0.0075 Img2Txt: 0.6660  Txt2Img: 0.6843
# test Loss: 0.0135 Img2Txt: 0.6660  Txt2Img: 0.6843
#
# Epoch 59/500
# --------------------
# train Loss: 0.0074 Img2Txt: 0.6420  Txt2Img: 0.6922
# test Loss: 0.0131 Img2Txt: 0.6420  Txt2Img: 0.6922
#
# Epoch 60/500
# --------------------
# train Loss: 0.0074 Img2Txt: 0.6615  Txt2Img: 0.6908
# test Loss: 0.0134 Img2Txt: 0.6615  Txt2Img: 0.6908
#
# Epoch 61/500
# --------------------
# train Loss: 0.0076 Img2Txt: 0.6510  Txt2Img: 0.6787
# test Loss: 0.0133 Img2Txt: 0.6510  Txt2Img: 0.6787
#
# Epoch 62/500
# --------------------
# train Loss: 0.0073 Img2Txt: 0.6412  Txt2Img: 0.6814
# test Loss: 0.0133 Img2Txt: 0.6412  Txt2Img: 0.6814
#
# Epoch 63/500
# --------------------
# train Loss: 0.0073 Img2Txt: 0.6643  Txt2Img: 0.6764
# test Loss: 0.0132 Img2Txt: 0.6643  Txt2Img: 0.6764
#
# Epoch 64/500
# --------------------
# train Loss: 0.0073 Img2Txt: 0.6559  Txt2Img: 0.6974
# test Loss: 0.0133 Img2Txt: 0.6559  Txt2Img: 0.6974
#
# Epoch 65/500
# --------------------
# train Loss: 0.0072 Img2Txt: 0.6482  Txt2Img: 0.6850
# test Loss: 0.0132 Img2Txt: 0.6482  Txt2Img: 0.6850
#
# Epoch 66/500
# --------------------
# train Loss: 0.0070 Img2Txt: 0.6538  Txt2Img: 0.6753
# test Loss: 0.0131 Img2Txt: 0.6538  Txt2Img: 0.6753
#
# Epoch 67/500
# --------------------
# train Loss: 0.0071 Img2Txt: 0.6660  Txt2Img: 0.6875
# test Loss: 0.0130 Img2Txt: 0.6660  Txt2Img: 0.6875
#
# Epoch 68/500
# --------------------
# train Loss: 0.0070 Img2Txt: 0.6374  Txt2Img: 0.6839
# test Loss: 0.0134 Img2Txt: 0.6374  Txt2Img: 0.6839
#
# Epoch 69/500
# --------------------
# train Loss: 0.0072 Img2Txt: 0.6592  Txt2Img: 0.6894
# test Loss: 0.0134 Img2Txt: 0.6592  Txt2Img: 0.6894
#
# Epoch 70/500
# --------------------
# train Loss: 0.0072 Img2Txt: 0.6517  Txt2Img: 0.6859
# test Loss: 0.0131 Img2Txt: 0.6517  Txt2Img: 0.6859
#
# Epoch 71/500
# --------------------
# train Loss: 0.0068 Img2Txt: 0.6598  Txt2Img: 0.6691
# test Loss: 0.0131 Img2Txt: 0.6598  Txt2Img: 0.6691
#
# Epoch 72/500
# --------------------
# train Loss: 0.0073 Img2Txt: 0.6496  Txt2Img: 0.6957
# test Loss: 0.0131 Img2Txt: 0.6496  Txt2Img: 0.6957
#
# Epoch 73/500
# --------------------
# train Loss: 0.0069 Img2Txt: 0.6487  Txt2Img: 0.6859
# test Loss: 0.0133 Img2Txt: 0.6487  Txt2Img: 0.6859
#
# Epoch 74/500
# --------------------
# train Loss: 0.0071 Img2Txt: 0.6181  Txt2Img: 0.6819
# test Loss: 0.0133 Img2Txt: 0.6181  Txt2Img: 0.6819
#
# Epoch 75/500
# --------------------
# train Loss: 0.0069 Img2Txt: 0.6598  Txt2Img: 0.6840
# test Loss: 0.0130 Img2Txt: 0.6598  Txt2Img: 0.6840
#
# Epoch 76/500
# --------------------
# train Loss: 0.0067 Img2Txt: 0.6457  Txt2Img: 0.6936
# test Loss: 0.0131 Img2Txt: 0.6457  Txt2Img: 0.6936
#
# Epoch 77/500
# --------------------
# train Loss: 0.0069 Img2Txt: 0.6440  Txt2Img: 0.6808
# test Loss: 0.0133 Img2Txt: 0.6440  Txt2Img: 0.6808
#
# Epoch 78/500
# --------------------
# train Loss: 0.0069 Img2Txt: 0.6517  Txt2Img: 0.6862
# test Loss: 0.0131 Img2Txt: 0.6517  Txt2Img: 0.6862
#
# Epoch 79/500
# --------------------
# train Loss: 0.0068 Img2Txt: 0.6280  Txt2Img: 0.6800
# test Loss: 0.0130 Img2Txt: 0.6280  Txt2Img: 0.6800
#
# Epoch 80/500
# --------------------
# train Loss: 0.0070 Img2Txt: 0.6344  Txt2Img: 0.6720
# test Loss: 0.0132 Img2Txt: 0.6344  Txt2Img: 0.6720
#
# Epoch 81/500
# --------------------
# train Loss: 0.0072 Img2Txt: 0.6573  Txt2Img: 0.6899
# test Loss: 0.0132 Img2Txt: 0.6573  Txt2Img: 0.6899
#
# Epoch 82/500
# --------------------
# train Loss: 0.0065 Img2Txt: 0.6423  Txt2Img: 0.6884
# test Loss: 0.0129 Img2Txt: 0.6423  Txt2Img: 0.6884
#
# Epoch 83/500
# --------------------
# train Loss: 0.0068 Img2Txt: 0.6209  Txt2Img: 0.6685
# test Loss: 0.0131 Img2Txt: 0.6209  Txt2Img: 0.6685
#
# Epoch 84/500
# --------------------
# train Loss: 0.0069 Img2Txt: 0.6470  Txt2Img: 0.6840
# test Loss: 0.0133 Img2Txt: 0.6470  Txt2Img: 0.6840
#
# Epoch 85/500
# --------------------
# train Loss: 0.0068 Img2Txt: 0.6463  Txt2Img: 0.6797
# test Loss: 0.0130 Img2Txt: 0.6463  Txt2Img: 0.6797
#
# Epoch 86/500
# --------------------
# train Loss: 0.0069 Img2Txt: 0.6239  Txt2Img: 0.6772
# test Loss: 0.0132 Img2Txt: 0.6239  Txt2Img: 0.6772
#
# Epoch 87/500
# --------------------
# train Loss: 0.0067 Img2Txt: 0.6271  Txt2Img: 0.6711
# test Loss: 0.0131 Img2Txt: 0.6271  Txt2Img: 0.6711
#
# Epoch 88/500
# --------------------
# train Loss: 0.0069 Img2Txt: 0.6276  Txt2Img: 0.6851
# test Loss: 0.0132 Img2Txt: 0.6276  Txt2Img: 0.6851
#
# Epoch 89/500
# --------------------
# train Loss: 0.0068 Img2Txt: 0.6444  Txt2Img: 0.6765
# test Loss: 0.0131 Img2Txt: 0.6444  Txt2Img: 0.6765
#
# Epoch 90/500
# --------------------
# train Loss: 0.0065 Img2Txt: 0.6577  Txt2Img: 0.6880
# test Loss: 0.0129 Img2Txt: 0.6577  Txt2Img: 0.6880
#
# Epoch 91/500
# --------------------
# train Loss: 0.0066 Img2Txt: 0.6224  Txt2Img: 0.6743
# test Loss: 0.0130 Img2Txt: 0.6224  Txt2Img: 0.6743
#
# Epoch 92/500
# --------------------
# train Loss: 0.0069 Img2Txt: 0.6481  Txt2Img: 0.6852
# test Loss: 0.0132 Img2Txt: 0.6481  Txt2Img: 0.6852
#
# Epoch 93/500
# --------------------
# train Loss: 0.0067 Img2Txt: 0.6382  Txt2Img: 0.6722
# test Loss: 0.0130 Img2Txt: 0.6382  Txt2Img: 0.6722
#
# Epoch 94/500
# --------------------
# train Loss: 0.0066 Img2Txt: 0.6441  Txt2Img: 0.6810
# test Loss: 0.0131 Img2Txt: 0.6441  Txt2Img: 0.6810
#
# Epoch 95/500
# --------------------
# train Loss: 0.0067 Img2Txt: 0.6272  Txt2Img: 0.6825
# test Loss: 0.0131 Img2Txt: 0.6272  Txt2Img: 0.6825
#
# Epoch 96/500
# --------------------
# train Loss: 0.0069 Img2Txt: 0.6349  Txt2Img: 0.6797
# test Loss: 0.0133 Img2Txt: 0.6349  Txt2Img: 0.6797
#
# Epoch 97/500
# --------------------
# train Loss: 0.0069 Img2Txt: 0.6440  Txt2Img: 0.6797
# test Loss: 0.0129 Img2Txt: 0.6440  Txt2Img: 0.6797
#
# Epoch 98/500
# --------------------
# train Loss: 0.0064 Img2Txt: 0.6599  Txt2Img: 0.6826
# test Loss: 0.0129 Img2Txt: 0.6599  Txt2Img: 0.6826
#
# Epoch 99/500
# --------------------
# train Loss: 0.0063 Img2Txt: 0.6325  Txt2Img: 0.6806
# test Loss: 0.0130 Img2Txt: 0.6325  Txt2Img: 0.6806
#
# Epoch 100/500
# --------------------
# train Loss: 0.0065 Img2Txt: 0.6486  Txt2Img: 0.6777
# test Loss: 0.0130 Img2Txt: 0.6486  Txt2Img: 0.6777
#
# Epoch 101/500
# --------------------
# train Loss: 0.0067 Img2Txt: 0.6552  Txt2Img: 0.6777
# test Loss: 0.0130 Img2Txt: 0.6552  Txt2Img: 0.6777
#
# Epoch 102/500
# --------------------
# train Loss: 0.0064 Img2Txt: 0.6406  Txt2Img: 0.6820
# test Loss: 0.0130 Img2Txt: 0.6406  Txt2Img: 0.6820
#
# Epoch 103/500
# --------------------
# train Loss: 0.0070 Img2Txt: 0.6560  Txt2Img: 0.6905
# test Loss: 0.0129 Img2Txt: 0.6560  Txt2Img: 0.6905
#
# Epoch 104/500
# --------------------
# train Loss: 0.0062 Img2Txt: 0.6267  Txt2Img: 0.6771
# test Loss: 0.0131 Img2Txt: 0.6267  Txt2Img: 0.6771
#
# Epoch 105/500
# --------------------
# train Loss: 0.0067 Img2Txt: 0.6493  Txt2Img: 0.6763
# test Loss: 0.0130 Img2Txt: 0.6493  Txt2Img: 0.6763
#
# Epoch 106/500
# --------------------
# train Loss: 0.0062 Img2Txt: 0.6414  Txt2Img: 0.6774
# test Loss: 0.0129 Img2Txt: 0.6414  Txt2Img: 0.6774
#
# Epoch 107/500
# --------------------
# train Loss: 0.0065 Img2Txt: 0.6470  Txt2Img: 0.6826
# test Loss: 0.0129 Img2Txt: 0.6470  Txt2Img: 0.6826
#
# Epoch 108/500
# --------------------
# train Loss: 0.0062 Img2Txt: 0.6258  Txt2Img: 0.6738
# test Loss: 0.0131 Img2Txt: 0.6258  Txt2Img: 0.6738
#
# Epoch 109/500
# --------------------
# train Loss: 0.0070 Img2Txt: 0.6532  Txt2Img: 0.6807
# test Loss: 0.0129 Img2Txt: 0.6532  Txt2Img: 0.6807
#
# Epoch 110/500
# --------------------
# train Loss: 0.0060 Img2Txt: 0.6341  Txt2Img: 0.6663
# test Loss: 0.0129 Img2Txt: 0.6341  Txt2Img: 0.6663
#
# Epoch 111/500
# --------------------
# train Loss: 0.0066 Img2Txt: 0.6565  Txt2Img: 0.6825
# test Loss: 0.0129 Img2Txt: 0.6565  Txt2Img: 0.6825
#
# Epoch 112/500
# --------------------
# train Loss: 0.0061 Img2Txt: 0.6296  Txt2Img: 0.6787
# test Loss: 0.0130 Img2Txt: 0.6296  Txt2Img: 0.6787
#
# Epoch 113/500
# --------------------
# train Loss: 0.0067 Img2Txt: 0.6499  Txt2Img: 0.6755
# test Loss: 0.0129 Img2Txt: 0.6499  Txt2Img: 0.6755
#
# Epoch 114/500
# --------------------
# train Loss: 0.0059 Img2Txt: 0.6382  Txt2Img: 0.6700
# test Loss: 0.0129 Img2Txt: 0.6382  Txt2Img: 0.6700
#
# Epoch 115/500
# --------------------
# train Loss: 0.0065 Img2Txt: 0.6521  Txt2Img: 0.6857
# test Loss: 0.0129 Img2Txt: 0.6521  Txt2Img: 0.6857
#
# Epoch 116/500
# --------------------
# train Loss: 0.0059 Img2Txt: 0.6379  Txt2Img: 0.6855
# test Loss: 0.0129 Img2Txt: 0.6379  Txt2Img: 0.6855
#
# Epoch 117/500
# --------------------
# train Loss: 0.0065 Img2Txt: 0.6503  Txt2Img: 0.6824
# test Loss: 0.0128 Img2Txt: 0.6503  Txt2Img: 0.6824
#
# Epoch 118/500
# --------------------
# train Loss: 0.0057 Img2Txt: 0.6513  Txt2Img: 0.6784
# test Loss: 0.0128 Img2Txt: 0.6513  Txt2Img: 0.6784
#
# Epoch 119/500
# --------------------
# train Loss: 0.0063 Img2Txt: 0.6477  Txt2Img: 0.6886
# test Loss: 0.0129 Img2Txt: 0.6477  Txt2Img: 0.6886
#
# Epoch 120/500
# --------------------
# train Loss: 0.0061 Img2Txt: 0.6418  Txt2Img: 0.6799
# test Loss: 0.0128 Img2Txt: 0.6418  Txt2Img: 0.6799
#
# Epoch 121/500
# --------------------
# train Loss: 0.0062 Img2Txt: 0.6530  Txt2Img: 0.6781
# test Loss: 0.0129 Img2Txt: 0.6530  Txt2Img: 0.6781
#
# Epoch 122/500
# --------------------
# train Loss: 0.0060 Img2Txt: 0.6597  Txt2Img: 0.6817
# test Loss: 0.0128 Img2Txt: 0.6597  Txt2Img: 0.6817
#
# Epoch 123/500
# --------------------
# train Loss: 0.0061 Img2Txt: 0.6449  Txt2Img: 0.6836
# test Loss: 0.0129 Img2Txt: 0.6449  Txt2Img: 0.6836
#
# Epoch 124/500
# --------------------
# train Loss: 0.0061 Img2Txt: 0.6523  Txt2Img: 0.6805
# test Loss: 0.0127 Img2Txt: 0.6523  Txt2Img: 0.6805
#
# Epoch 125/500
# --------------------
# train Loss: 0.0059 Img2Txt: 0.6528  Txt2Img: 0.6839
# test Loss: 0.0128 Img2Txt: 0.6528  Txt2Img: 0.6839
#
# Epoch 126/500
# --------------------
# train Loss: 0.0059 Img2Txt: 0.6619  Txt2Img: 0.6886
# test Loss: 0.0127 Img2Txt: 0.6619  Txt2Img: 0.6886
#
# Epoch 127/500
# --------------------
# train Loss: 0.0060 Img2Txt: 0.6441  Txt2Img: 0.6792
# test Loss: 0.0128 Img2Txt: 0.6441  Txt2Img: 0.6792
#
# Epoch 128/500
# --------------------
# train Loss: 0.0059 Img2Txt: 0.6594  Txt2Img: 0.6848
# test Loss: 0.0127 Img2Txt: 0.6594  Txt2Img: 0.6848
#
# Epoch 129/500
# --------------------
# train Loss: 0.0059 Img2Txt: 0.6448  Txt2Img: 0.6834
# test Loss: 0.0128 Img2Txt: 0.6448  Txt2Img: 0.6834
#
# Epoch 130/500
# --------------------
# train Loss: 0.0058 Img2Txt: 0.6636  Txt2Img: 0.6928
# test Loss: 0.0127 Img2Txt: 0.6636  Txt2Img: 0.6928
#
# Epoch 131/500
# --------------------
# train Loss: 0.0058 Img2Txt: 0.6383  Txt2Img: 0.6800
# test Loss: 0.0126 Img2Txt: 0.6383  Txt2Img: 0.6800
#
# Epoch 132/500
# --------------------
# train Loss: 0.0058 Img2Txt: 0.6563  Txt2Img: 0.6808
# test Loss: 0.0128 Img2Txt: 0.6563  Txt2Img: 0.6808
#
# Epoch 133/500
# --------------------
# train Loss: 0.0059 Img2Txt: 0.6504  Txt2Img: 0.6864
# test Loss: 0.0127 Img2Txt: 0.6504  Txt2Img: 0.6864
#
# Epoch 134/500
# --------------------
# train Loss: 0.0056 Img2Txt: 0.6617  Txt2Img: 0.6790
# test Loss: 0.0126 Img2Txt: 0.6617  Txt2Img: 0.6790
#
# Epoch 135/500
# --------------------
# train Loss: 0.0059 Img2Txt: 0.6376  Txt2Img: 0.6800
# test Loss: 0.0128 Img2Txt: 0.6376  Txt2Img: 0.6800
#
# Epoch 136/500
# --------------------
# train Loss: 0.0058 Img2Txt: 0.6509  Txt2Img: 0.6823
# test Loss: 0.0127 Img2Txt: 0.6509  Txt2Img: 0.6823
#
# Epoch 137/500
# --------------------
# train Loss: 0.0059 Img2Txt: 0.6255  Txt2Img: 0.6783
# test Loss: 0.0128 Img2Txt: 0.6255  Txt2Img: 0.6783
#
# Epoch 138/500
# --------------------
# train Loss: 0.0058 Img2Txt: 0.6432  Txt2Img: 0.6820
# test Loss: 0.0127 Img2Txt: 0.6432  Txt2Img: 0.6820
#
# Epoch 139/500
# --------------------
# train Loss: 0.0059 Img2Txt: 0.6504  Txt2Img: 0.6855
# test Loss: 0.0127 Img2Txt: 0.6504  Txt2Img: 0.6855
#
# Epoch 140/500
# --------------------
# train Loss: 0.0057 Img2Txt: 0.6481  Txt2Img: 0.6795
# test Loss: 0.0129 Img2Txt: 0.6481  Txt2Img: 0.6795
#
# Epoch 141/500
# --------------------
# train Loss: 0.0059 Img2Txt: 0.6251  Txt2Img: 0.6758
# test Loss: 0.0126 Img2Txt: 0.6251  Txt2Img: 0.6758
#
# Epoch 142/500
# --------------------
# train Loss: 0.0057 Img2Txt: 0.6460  Txt2Img: 0.6773
# test Loss: 0.0129 Img2Txt: 0.6460  Txt2Img: 0.6773
#
# Epoch 143/500
# --------------------
# train Loss: 0.0058 Img2Txt: 0.6480  Txt2Img: 0.6800
# test Loss: 0.0127 Img2Txt: 0.6480  Txt2Img: 0.6800
#
# Epoch 144/500
# --------------------
# train Loss: 0.0056 Img2Txt: 0.6438  Txt2Img: 0.6775
# test Loss: 0.0128 Img2Txt: 0.6438  Txt2Img: 0.6775
#
# Epoch 145/500
# --------------------
# train Loss: 0.0057 Img2Txt: 0.6333  Txt2Img: 0.6737
# test Loss: 0.0127 Img2Txt: 0.6333  Txt2Img: 0.6737
#
# Epoch 146/500
# --------------------
# train Loss: 0.0057 Img2Txt: 0.6453  Txt2Img: 0.6827
# test Loss: 0.0128 Img2Txt: 0.6453  Txt2Img: 0.6827
#
# Epoch 147/500
# --------------------
# train Loss: 0.0056 Img2Txt: 0.6487  Txt2Img: 0.6817
# test Loss: 0.0127 Img2Txt: 0.6487  Txt2Img: 0.6817
#
# Epoch 148/500
# --------------------
# train Loss: 0.0057 Img2Txt: 0.6349  Txt2Img: 0.6697
# test Loss: 0.0129 Img2Txt: 0.6349  Txt2Img: 0.6697
#
# Epoch 149/500
# --------------------
# train Loss: 0.0058 Img2Txt: 0.6337  Txt2Img: 0.6765
# test Loss: 0.0127 Img2Txt: 0.6337  Txt2Img: 0.6765
#
# Epoch 150/500
# --------------------
# train Loss: 0.0057 Img2Txt: 0.6420  Txt2Img: 0.6779
# test Loss: 0.0127 Img2Txt: 0.6420  Txt2Img: 0.6779
#
# Epoch 151/500
# --------------------
# train Loss: 0.0056 Img2Txt: 0.6438  Txt2Img: 0.6825
# test Loss: 0.0126 Img2Txt: 0.6438  Txt2Img: 0.6825
#
# Epoch 152/500
# --------------------
# train Loss: 0.0056 Img2Txt: 0.6403  Txt2Img: 0.6719
# test Loss: 0.0129 Img2Txt: 0.6403  Txt2Img: 0.6719
#
# Epoch 153/500
# --------------------
# train Loss: 0.0056 Img2Txt: 0.6473  Txt2Img: 0.6764
# test Loss: 0.0125 Img2Txt: 0.6473  Txt2Img: 0.6764
#
# Epoch 154/500
# --------------------
# train Loss: 0.0054 Img2Txt: 0.6391  Txt2Img: 0.6803
# test Loss: 0.0127 Img2Txt: 0.6391  Txt2Img: 0.6803
#
# Epoch 155/500
# --------------------
# train Loss: 0.0056 Img2Txt: 0.6347  Txt2Img: 0.6732
# test Loss: 0.0126 Img2Txt: 0.6347  Txt2Img: 0.6732
#
# Epoch 156/500
# --------------------
# train Loss: 0.0056 Img2Txt: 0.6486  Txt2Img: 0.6770
# test Loss: 0.0128 Img2Txt: 0.6486  Txt2Img: 0.6770
#
# Epoch 157/500
# --------------------
# train Loss: 0.0054 Img2Txt: 0.6432  Txt2Img: 0.6776
# test Loss: 0.0126 Img2Txt: 0.6432  Txt2Img: 0.6776
#
# Epoch 158/500
# --------------------
# train Loss: 0.0054 Img2Txt: 0.6320  Txt2Img: 0.6763
# test Loss: 0.0128 Img2Txt: 0.6320  Txt2Img: 0.6763
#
# Epoch 159/500
# --------------------
# train Loss: 0.0057 Img2Txt: 0.6370  Txt2Img: 0.6742
# test Loss: 0.0126 Img2Txt: 0.6370  Txt2Img: 0.6742
#
# Epoch 160/500
# --------------------
# train Loss: 0.0055 Img2Txt: 0.6513  Txt2Img: 0.6769
# test Loss: 0.0127 Img2Txt: 0.6513  Txt2Img: 0.6769
#
# Epoch 161/500
# --------------------
# train Loss: 0.0055 Img2Txt: 0.6446  Txt2Img: 0.6802
# test Loss: 0.0126 Img2Txt: 0.6446  Txt2Img: 0.6802
#
# Epoch 162/500
# --------------------
# train Loss: 0.0054 Img2Txt: 0.6341  Txt2Img: 0.6724
# test Loss: 0.0128 Img2Txt: 0.6341  Txt2Img: 0.6724
#
# Epoch 163/500
# --------------------
# train Loss: 0.0055 Img2Txt: 0.6368  Txt2Img: 0.6722
# test Loss: 0.0126 Img2Txt: 0.6368  Txt2Img: 0.6722
#
# Epoch 164/500
# --------------------
# train Loss: 0.0055 Img2Txt: 0.6513  Txt2Img: 0.6754
# test Loss: 0.0126 Img2Txt: 0.6513  Txt2Img: 0.6754
#
# Epoch 165/500
# --------------------
# train Loss: 0.0053 Img2Txt: 0.6457  Txt2Img: 0.6789
# test Loss: 0.0126 Img2Txt: 0.6457  Txt2Img: 0.6789
#
# Epoch 166/500
# --------------------
# train Loss: 0.0054 Img2Txt: 0.6430  Txt2Img: 0.6745
# test Loss: 0.0127 Img2Txt: 0.6430  Txt2Img: 0.6745
#
# Epoch 167/500
# --------------------
# train Loss: 0.0054 Img2Txt: 0.6286  Txt2Img: 0.6695
# test Loss: 0.0126 Img2Txt: 0.6286  Txt2Img: 0.6695
#
# Epoch 168/500
# --------------------
# train Loss: 0.0056 Img2Txt: 0.6467  Txt2Img: 0.6752
# test Loss: 0.0127 Img2Txt: 0.6467  Txt2Img: 0.6752
#
# Epoch 169/500
# --------------------
# train Loss: 0.0053 Img2Txt: 0.6425  Txt2Img: 0.6749
# test Loss: 0.0125 Img2Txt: 0.6425  Txt2Img: 0.6749
#
# Epoch 170/500
# --------------------
# train Loss: 0.0054 Img2Txt: 0.6504  Txt2Img: 0.6750
# test Loss: 0.0126 Img2Txt: 0.6504  Txt2Img: 0.6750
#
# Epoch 171/500
# --------------------
# train Loss: 0.0052 Img2Txt: 0.6291  Txt2Img: 0.6721
# test Loss: 0.0126 Img2Txt: 0.6291  Txt2Img: 0.6721
#
# Epoch 172/500
# --------------------
# train Loss: 0.0054 Img2Txt: 0.6482  Txt2Img: 0.6751
# test Loss: 0.0126 Img2Txt: 0.6482  Txt2Img: 0.6751
#
# Epoch 173/500
# --------------------
# train Loss: 0.0053 Img2Txt: 0.6377  Txt2Img: 0.6781
# test Loss: 0.0125 Img2Txt: 0.6377  Txt2Img: 0.6781
#
# Epoch 174/500
# --------------------
# train Loss: 0.0054 Img2Txt: 0.6515  Txt2Img: 0.6733
# test Loss: 0.0126 Img2Txt: 0.6515  Txt2Img: 0.6733
#
# Epoch 175/500
# --------------------
# train Loss: 0.0052 Img2Txt: 0.6464  Txt2Img: 0.6840
# test Loss: 0.0125 Img2Txt: 0.6464  Txt2Img: 0.6840
#
# Epoch 176/500
# --------------------
# train Loss: 0.0052 Img2Txt: 0.6491  Txt2Img: 0.6773
# test Loss: 0.0126 Img2Txt: 0.6491  Txt2Img: 0.6773
#
# Epoch 177/500
# --------------------
# train Loss: 0.0052 Img2Txt: 0.6340  Txt2Img: 0.6752
# test Loss: 0.0125 Img2Txt: 0.6340  Txt2Img: 0.6752
#
# Epoch 178/500
# --------------------
# train Loss: 0.0052 Img2Txt: 0.6429  Txt2Img: 0.6774
# test Loss: 0.0126 Img2Txt: 0.6429  Txt2Img: 0.6774
#
# Epoch 179/500
# --------------------
# train Loss: 0.0052 Img2Txt: 0.6477  Txt2Img: 0.6768
# test Loss: 0.0125 Img2Txt: 0.6477  Txt2Img: 0.6768
#
# Epoch 180/500
# --------------------
# train Loss: 0.0051 Img2Txt: 0.6438  Txt2Img: 0.6757
# test Loss: 0.0126 Img2Txt: 0.6438  Txt2Img: 0.6757
#
# Epoch 181/500
# --------------------
# train Loss: 0.0053 Img2Txt: 0.6380  Txt2Img: 0.6749
# test Loss: 0.0125 Img2Txt: 0.6380  Txt2Img: 0.6749
#
# Epoch 182/500
# --------------------
# train Loss: 0.0052 Img2Txt: 0.6407  Txt2Img: 0.6789
# test Loss: 0.0126 Img2Txt: 0.6407  Txt2Img: 0.6789
#
# Epoch 183/500
# --------------------
# train Loss: 0.0052 Img2Txt: 0.6388  Txt2Img: 0.6760
# test Loss: 0.0124 Img2Txt: 0.6388  Txt2Img: 0.6760
#
# Epoch 184/500
# --------------------
# train Loss: 0.0050 Img2Txt: 0.6440  Txt2Img: 0.6738
# test Loss: 0.0126 Img2Txt: 0.6440  Txt2Img: 0.6738
#
# Epoch 185/500
# --------------------
# train Loss: 0.0052 Img2Txt: 0.6437  Txt2Img: 0.6784
# test Loss: 0.0125 Img2Txt: 0.6437  Txt2Img: 0.6784
#
# Epoch 186/500
# --------------------
# train Loss: 0.0051 Img2Txt: 0.6506  Txt2Img: 0.6749
# test Loss: 0.0127 Img2Txt: 0.6506  Txt2Img: 0.6749
#
# Epoch 187/500
# --------------------
# train Loss: 0.0052 Img2Txt: 0.6282  Txt2Img: 0.6743
# test Loss: 0.0124 Img2Txt: 0.6282  Txt2Img: 0.6743
#
# Epoch 188/500
# --------------------
# train Loss: 0.0050 Img2Txt: 0.6430  Txt2Img: 0.6773
# test Loss: 0.0126 Img2Txt: 0.6430  Txt2Img: 0.6773
#
# Epoch 189/500
# --------------------
# train Loss: 0.0051 Img2Txt: 0.6401  Txt2Img: 0.6718
# test Loss: 0.0126 Img2Txt: 0.6401  Txt2Img: 0.6718
#
# Epoch 190/500
# --------------------
# train Loss: 0.0050 Img2Txt: 0.6472  Txt2Img: 0.6755
# test Loss: 0.0127 Img2Txt: 0.6472  Txt2Img: 0.6755
#
# Epoch 191/500
# --------------------
# train Loss: 0.0051 Img2Txt: 0.6385  Txt2Img: 0.6776
# test Loss: 0.0124 Img2Txt: 0.6385  Txt2Img: 0.6776
#
# Epoch 192/500
# --------------------
# train Loss: 0.0049 Img2Txt: 0.6474  Txt2Img: 0.6792
# test Loss: 0.0125 Img2Txt: 0.6474  Txt2Img: 0.6792
#
# Epoch 193/500
# --------------------
# train Loss: 0.0052 Img2Txt: 0.6309  Txt2Img: 0.6732
# test Loss: 0.0126 Img2Txt: 0.6309  Txt2Img: 0.6732
#
# Epoch 194/500
# --------------------
# train Loss: 0.0051 Img2Txt: 0.6339  Txt2Img: 0.6749
# test Loss: 0.0126 Img2Txt: 0.6339  Txt2Img: 0.6749
#
# Epoch 195/500
# --------------------
# train Loss: 0.0051 Img2Txt: 0.6631  Txt2Img: 0.6851
# test Loss: 0.0125 Img2Txt: 0.6631  Txt2Img: 0.6851
#
# Epoch 196/500
# --------------------
# train Loss: 0.0050 Img2Txt: 0.6325  Txt2Img: 0.6756
# test Loss: 0.0126 Img2Txt: 0.6325  Txt2Img: 0.6756
#
# Epoch 197/500
# --------------------
# train Loss: 0.0051 Img2Txt: 0.6592  Txt2Img: 0.6796
# test Loss: 0.0125 Img2Txt: 0.6592  Txt2Img: 0.6796
#
# Epoch 198/500
# --------------------
# train Loss: 0.0050 Img2Txt: 0.6323  Txt2Img: 0.6738
# test Loss: 0.0125 Img2Txt: 0.6323  Txt2Img: 0.6738
#
# Epoch 199/500
# --------------------
# train Loss: 0.0050 Img2Txt: 0.6582  Txt2Img: 0.6865
# test Loss: 0.0125 Img2Txt: 0.6582  Txt2Img: 0.6865
#
# Epoch 200/500
# --------------------
# train Loss: 0.0049 Img2Txt: 0.6301  Txt2Img: 0.6668
# test Loss: 0.0126 Img2Txt: 0.6301  Txt2Img: 0.6668
#
# Epoch 201/500
# --------------------
# train Loss: 0.0051 Img2Txt: 0.6595  Txt2Img: 0.6811
# test Loss: 0.0125 Img2Txt: 0.6595  Txt2Img: 0.6811
#
# Epoch 202/500
# --------------------
# train Loss: 0.0049 Img2Txt: 0.6423  Txt2Img: 0.6753
# test Loss: 0.0125 Img2Txt: 0.6423  Txt2Img: 0.6753
#
# Epoch 203/500
# --------------------
# train Loss: 0.0049 Img2Txt: 0.6560  Txt2Img: 0.6847
# test Loss: 0.0126 Img2Txt: 0.6560  Txt2Img: 0.6847
#
# Epoch 204/500
# --------------------
# train Loss: 0.0049 Img2Txt: 0.6420  Txt2Img: 0.6727
# test Loss: 0.0125 Img2Txt: 0.6420  Txt2Img: 0.6727
#
# Epoch 205/500
# --------------------
# train Loss: 0.0052 Img2Txt: 0.6592  Txt2Img: 0.6817
# test Loss: 0.0126 Img2Txt: 0.6592  Txt2Img: 0.6817
#
# Epoch 206/500
# --------------------
# train Loss: 0.0048 Img2Txt: 0.6439  Txt2Img: 0.6756
# test Loss: 0.0124 Img2Txt: 0.6439  Txt2Img: 0.6756
#
# Epoch 207/500
# --------------------
# train Loss: 0.0049 Img2Txt: 0.6514  Txt2Img: 0.6863
# test Loss: 0.0126 Img2Txt: 0.6514  Txt2Img: 0.6863
#
# Epoch 208/500
# --------------------
# train Loss: 0.0047 Img2Txt: 0.6393  Txt2Img: 0.6718
# test Loss: 0.0124 Img2Txt: 0.6393  Txt2Img: 0.6718
#
# Epoch 209/500
# --------------------
# train Loss: 0.0052 Img2Txt: 0.6523  Txt2Img: 0.6798
# test Loss: 0.0126 Img2Txt: 0.6523  Txt2Img: 0.6798
#
# Epoch 210/500
# --------------------
# train Loss: 0.0048 Img2Txt: 0.6439  Txt2Img: 0.6749
# test Loss: 0.0124 Img2Txt: 0.6439  Txt2Img: 0.6749
#
# Epoch 211/500
# --------------------
# train Loss: 0.0049 Img2Txt: 0.6592  Txt2Img: 0.6790
# test Loss: 0.0127 Img2Txt: 0.6592  Txt2Img: 0.6790
#
# Epoch 212/500
# --------------------
# train Loss: 0.0048 Img2Txt: 0.6441  Txt2Img: 0.6721
# test Loss: 0.0124 Img2Txt: 0.6441  Txt2Img: 0.6721
#
# Epoch 213/500
# --------------------
# train Loss: 0.0050 Img2Txt: 0.6593  Txt2Img: 0.6904
# test Loss: 0.0124 Img2Txt: 0.6593  Txt2Img: 0.6904
#
# Epoch 214/500
# --------------------
# train Loss: 0.0047 Img2Txt: 0.6414  Txt2Img: 0.6701
# test Loss: 0.0124 Img2Txt: 0.6414  Txt2Img: 0.6701
#
# Epoch 215/500
# --------------------
# train Loss: 0.0050 Img2Txt: 0.6600  Txt2Img: 0.6854
# test Loss: 0.0125 Img2Txt: 0.6600  Txt2Img: 0.6854
#
# Epoch 216/500
# --------------------
# train Loss: 0.0048 Img2Txt: 0.6403  Txt2Img: 0.6687
# test Loss: 0.0126 Img2Txt: 0.6403  Txt2Img: 0.6687
#
# Epoch 217/500
# --------------------
# train Loss: 0.0051 Img2Txt: 0.6609  Txt2Img: 0.6852
# test Loss: 0.0124 Img2Txt: 0.6609  Txt2Img: 0.6852
#
# Epoch 218/500
# --------------------
# train Loss: 0.0046 Img2Txt: 0.6422  Txt2Img: 0.6746
# test Loss: 0.0124 Img2Txt: 0.6422  Txt2Img: 0.6746
#
# Epoch 219/500
# --------------------
# train Loss: 0.0050 Img2Txt: 0.6663  Txt2Img: 0.6853
# test Loss: 0.0125 Img2Txt: 0.6663  Txt2Img: 0.6853
#
# Epoch 220/500
# --------------------
# train Loss: 0.0046 Img2Txt: 0.6368  Txt2Img: 0.6699
# test Loss: 0.0124 Img2Txt: 0.6368  Txt2Img: 0.6699
#
# Epoch 221/500
# --------------------
# train Loss: 0.0050 Img2Txt: 0.6570  Txt2Img: 0.6818
# test Loss: 0.0125 Img2Txt: 0.6570  Txt2Img: 0.6818
#
# Epoch 222/500
# --------------------
# train Loss: 0.0046 Img2Txt: 0.6393  Txt2Img: 0.6768
# test Loss: 0.0125 Img2Txt: 0.6393  Txt2Img: 0.6768
#
# Epoch 223/500
# --------------------
# train Loss: 0.0051 Img2Txt: 0.6595  Txt2Img: 0.6823
# test Loss: 0.0125 Img2Txt: 0.6595  Txt2Img: 0.6823
#
# Epoch 224/500
# --------------------
# train Loss: 0.0046 Img2Txt: 0.6377  Txt2Img: 0.6755
# test Loss: 0.0124 Img2Txt: 0.6377  Txt2Img: 0.6755
#
# Epoch 225/500
# --------------------
# train Loss: 0.0050 Img2Txt: 0.6627  Txt2Img: 0.6865
# test Loss: 0.0124 Img2Txt: 0.6627  Txt2Img: 0.6865
#
# Epoch 226/500
# --------------------
# train Loss: 0.0046 Img2Txt: 0.6384  Txt2Img: 0.6741
# test Loss: 0.0125 Img2Txt: 0.6384  Txt2Img: 0.6741
#
# Epoch 227/500
# --------------------
# train Loss: 0.0050 Img2Txt: 0.6553  Txt2Img: 0.6833
# test Loss: 0.0125 Img2Txt: 0.6553  Txt2Img: 0.6833
#
# Epoch 228/500
# --------------------
# train Loss: 0.0046 Img2Txt: 0.6419  Txt2Img: 0.6735
# test Loss: 0.0124 Img2Txt: 0.6419  Txt2Img: 0.6735
#
# Epoch 229/500
# --------------------
# train Loss: 0.0050 Img2Txt: 0.6601  Txt2Img: 0.6864
# test Loss: 0.0124 Img2Txt: 0.6601  Txt2Img: 0.6864
#
# Epoch 230/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6404  Txt2Img: 0.6717
# test Loss: 0.0125 Img2Txt: 0.6404  Txt2Img: 0.6717
#
# Epoch 231/500
# --------------------
# train Loss: 0.0050 Img2Txt: 0.6530  Txt2Img: 0.6831
# test Loss: 0.0125 Img2Txt: 0.6530  Txt2Img: 0.6831
#
# Epoch 232/500
# --------------------
# train Loss: 0.0045 Img2Txt: 0.6375  Txt2Img: 0.6757
# test Loss: 0.0125 Img2Txt: 0.6375  Txt2Img: 0.6757
#
# Epoch 233/500
# --------------------
# train Loss: 0.0049 Img2Txt: 0.6586  Txt2Img: 0.6789
# test Loss: 0.0125 Img2Txt: 0.6586  Txt2Img: 0.6789
#
# Epoch 234/500
# --------------------
# train Loss: 0.0046 Img2Txt: 0.6393  Txt2Img: 0.6804
# test Loss: 0.0124 Img2Txt: 0.6393  Txt2Img: 0.6804
#
# Epoch 235/500
# --------------------
# train Loss: 0.0049 Img2Txt: 0.6530  Txt2Img: 0.6824
# test Loss: 0.0124 Img2Txt: 0.6530  Txt2Img: 0.6824
#
# Epoch 236/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6361  Txt2Img: 0.6755
# test Loss: 0.0124 Img2Txt: 0.6361  Txt2Img: 0.6755
#
# Epoch 237/500
# --------------------
# train Loss: 0.0049 Img2Txt: 0.6543  Txt2Img: 0.6754
# test Loss: 0.0126 Img2Txt: 0.6543  Txt2Img: 0.6754
#
# Epoch 238/500
# --------------------
# train Loss: 0.0045 Img2Txt: 0.6363  Txt2Img: 0.6759
# test Loss: 0.0125 Img2Txt: 0.6363  Txt2Img: 0.6759
#
# Epoch 239/500
# --------------------
# train Loss: 0.0050 Img2Txt: 0.6616  Txt2Img: 0.6868
# test Loss: 0.0124 Img2Txt: 0.6616  Txt2Img: 0.6868
#
# Epoch 240/500
# --------------------
# train Loss: 0.0043 Img2Txt: 0.6371  Txt2Img: 0.6760
# test Loss: 0.0124 Img2Txt: 0.6371  Txt2Img: 0.6760
#
# Epoch 241/500
# --------------------
# train Loss: 0.0048 Img2Txt: 0.6573  Txt2Img: 0.6777
# test Loss: 0.0125 Img2Txt: 0.6573  Txt2Img: 0.6777
#
# Epoch 242/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6395  Txt2Img: 0.6692
# test Loss: 0.0125 Img2Txt: 0.6395  Txt2Img: 0.6692
#
# Epoch 243/500
# --------------------
# train Loss: 0.0048 Img2Txt: 0.6625  Txt2Img: 0.6888
# test Loss: 0.0123 Img2Txt: 0.6625  Txt2Img: 0.6888
#
# Epoch 244/500
# --------------------
# train Loss: 0.0043 Img2Txt: 0.6397  Txt2Img: 0.6801
# test Loss: 0.0124 Img2Txt: 0.6397  Txt2Img: 0.6801
#
# Epoch 245/500
# --------------------
# train Loss: 0.0048 Img2Txt: 0.6631  Txt2Img: 0.6776
# test Loss: 0.0124 Img2Txt: 0.6631  Txt2Img: 0.6776
#
# Epoch 246/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6377  Txt2Img: 0.6703
# test Loss: 0.0124 Img2Txt: 0.6377  Txt2Img: 0.6703
#
# Epoch 247/500
# --------------------
# train Loss: 0.0048 Img2Txt: 0.6576  Txt2Img: 0.6817
# test Loss: 0.0124 Img2Txt: 0.6576  Txt2Img: 0.6817
#
# Epoch 248/500
# --------------------
# train Loss: 0.0043 Img2Txt: 0.6409  Txt2Img: 0.6814
# test Loss: 0.0124 Img2Txt: 0.6409  Txt2Img: 0.6814
#
# Epoch 249/500
# --------------------
# train Loss: 0.0047 Img2Txt: 0.6651  Txt2Img: 0.6792
# test Loss: 0.0124 Img2Txt: 0.6651  Txt2Img: 0.6792
#
# Epoch 250/500
# --------------------
# train Loss: 0.0042 Img2Txt: 0.6346  Txt2Img: 0.6700
# test Loss: 0.0124 Img2Txt: 0.6346  Txt2Img: 0.6700
#
# Epoch 251/500
# --------------------
# train Loss: 0.0047 Img2Txt: 0.6555  Txt2Img: 0.6757
# test Loss: 0.0125 Img2Txt: 0.6555  Txt2Img: 0.6757
#
# Epoch 252/500
# --------------------
# train Loss: 0.0043 Img2Txt: 0.6400  Txt2Img: 0.6737
# test Loss: 0.0124 Img2Txt: 0.6400  Txt2Img: 0.6737
#
# Epoch 253/500
# --------------------
# train Loss: 0.0047 Img2Txt: 0.6623  Txt2Img: 0.6861
# test Loss: 0.0123 Img2Txt: 0.6623  Txt2Img: 0.6861
#
# Epoch 254/500
# --------------------
# train Loss: 0.0042 Img2Txt: 0.6356  Txt2Img: 0.6715
# test Loss: 0.0124 Img2Txt: 0.6356  Txt2Img: 0.6715
#
# Epoch 255/500
# --------------------
# train Loss: 0.0048 Img2Txt: 0.6602  Txt2Img: 0.6775
# test Loss: 0.0124 Img2Txt: 0.6602  Txt2Img: 0.6775
#
# Epoch 256/500
# --------------------
# train Loss: 0.0042 Img2Txt: 0.6442  Txt2Img: 0.6708
# test Loss: 0.0125 Img2Txt: 0.6442  Txt2Img: 0.6708
#
# Epoch 257/500
# --------------------
# train Loss: 0.0047 Img2Txt: 0.6604  Txt2Img: 0.6840
# test Loss: 0.0123 Img2Txt: 0.6604  Txt2Img: 0.6840
#
# Epoch 258/500
# --------------------
# train Loss: 0.0041 Img2Txt: 0.6370  Txt2Img: 0.6695
# test Loss: 0.0124 Img2Txt: 0.6370  Txt2Img: 0.6695
#
# Epoch 259/500
# --------------------
# train Loss: 0.0048 Img2Txt: 0.6652  Txt2Img: 0.6786
# test Loss: 0.0124 Img2Txt: 0.6652  Txt2Img: 0.6786
#
# Epoch 260/500
# --------------------
# train Loss: 0.0042 Img2Txt: 0.6378  Txt2Img: 0.6765
# test Loss: 0.0124 Img2Txt: 0.6378  Txt2Img: 0.6765
#
# Epoch 261/500
# --------------------
# train Loss: 0.0045 Img2Txt: 0.6568  Txt2Img: 0.6739
# test Loss: 0.0123 Img2Txt: 0.6568  Txt2Img: 0.6739
#
# Epoch 262/500
# --------------------
# train Loss: 0.0042 Img2Txt: 0.6418  Txt2Img: 0.6759
# test Loss: 0.0124 Img2Txt: 0.6418  Txt2Img: 0.6759
#
# Epoch 263/500
# --------------------
# train Loss: 0.0048 Img2Txt: 0.6627  Txt2Img: 0.6763
# test Loss: 0.0124 Img2Txt: 0.6627  Txt2Img: 0.6763
#
# Epoch 264/500
# --------------------
# train Loss: 0.0041 Img2Txt: 0.6436  Txt2Img: 0.6733
# test Loss: 0.0123 Img2Txt: 0.6436  Txt2Img: 0.6733
#
# Epoch 265/500
# --------------------
# train Loss: 0.0046 Img2Txt: 0.6610  Txt2Img: 0.6803
# test Loss: 0.0123 Img2Txt: 0.6610  Txt2Img: 0.6803
#
# Epoch 266/500
# --------------------
# train Loss: 0.0041 Img2Txt: 0.6424  Txt2Img: 0.6724
# test Loss: 0.0124 Img2Txt: 0.6424  Txt2Img: 0.6724
#
# Epoch 267/500
# --------------------
# train Loss: 0.0046 Img2Txt: 0.6675  Txt2Img: 0.6827
# test Loss: 0.0123 Img2Txt: 0.6675  Txt2Img: 0.6827
#
# Epoch 268/500
# --------------------
# train Loss: 0.0041 Img2Txt: 0.6414  Txt2Img: 0.6795
# test Loss: 0.0123 Img2Txt: 0.6414  Txt2Img: 0.6795
#
# Epoch 269/500
# --------------------
# train Loss: 0.0045 Img2Txt: 0.6621  Txt2Img: 0.6773
# test Loss: 0.0123 Img2Txt: 0.6621  Txt2Img: 0.6773
#
# Epoch 270/500
# --------------------
# train Loss: 0.0041 Img2Txt: 0.6439  Txt2Img: 0.6695
# test Loss: 0.0124 Img2Txt: 0.6439  Txt2Img: 0.6695
#
# Epoch 271/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6636  Txt2Img: 0.6768
# test Loss: 0.0123 Img2Txt: 0.6636  Txt2Img: 0.6768
#
# Epoch 272/500
# --------------------
# train Loss: 0.0041 Img2Txt: 0.6402  Txt2Img: 0.6756
# test Loss: 0.0123 Img2Txt: 0.6402  Txt2Img: 0.6756
#
# Epoch 273/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6652  Txt2Img: 0.6766
# test Loss: 0.0124 Img2Txt: 0.6652  Txt2Img: 0.6766
#
# Epoch 274/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6407  Txt2Img: 0.6762
# test Loss: 0.0123 Img2Txt: 0.6407  Txt2Img: 0.6762
#
# Epoch 275/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6605  Txt2Img: 0.6779
# test Loss: 0.0124 Img2Txt: 0.6605  Txt2Img: 0.6779
#
# Epoch 276/500
# --------------------
# train Loss: 0.0041 Img2Txt: 0.6408  Txt2Img: 0.6713
# test Loss: 0.0123 Img2Txt: 0.6408  Txt2Img: 0.6713
#
# Epoch 277/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6622  Txt2Img: 0.6744
# test Loss: 0.0123 Img2Txt: 0.6622  Txt2Img: 0.6744
#
# Epoch 278/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6434  Txt2Img: 0.6780
# test Loss: 0.0123 Img2Txt: 0.6434  Txt2Img: 0.6780
#
# Epoch 279/500
# --------------------
# train Loss: 0.0043 Img2Txt: 0.6600  Txt2Img: 0.6806
# test Loss: 0.0123 Img2Txt: 0.6600  Txt2Img: 0.6806
#
# Epoch 280/500
# --------------------
# train Loss: 0.0041 Img2Txt: 0.6436  Txt2Img: 0.6691
# test Loss: 0.0124 Img2Txt: 0.6436  Txt2Img: 0.6691
#
# Epoch 281/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6588  Txt2Img: 0.6788
# test Loss: 0.0123 Img2Txt: 0.6588  Txt2Img: 0.6788
#
# Epoch 282/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6429  Txt2Img: 0.6746
# test Loss: 0.0123 Img2Txt: 0.6429  Txt2Img: 0.6746
#
# Epoch 283/500
# --------------------
# train Loss: 0.0043 Img2Txt: 0.6536  Txt2Img: 0.6748
# test Loss: 0.0123 Img2Txt: 0.6536  Txt2Img: 0.6748
#
# Epoch 284/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6430  Txt2Img: 0.6739
# test Loss: 0.0124 Img2Txt: 0.6430  Txt2Img: 0.6739
#
# Epoch 285/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6606  Txt2Img: 0.6756
# test Loss: 0.0122 Img2Txt: 0.6606  Txt2Img: 0.6756
#
# Epoch 286/500
# --------------------
# train Loss: 0.0039 Img2Txt: 0.6362  Txt2Img: 0.6763
# test Loss: 0.0123 Img2Txt: 0.6362  Txt2Img: 0.6763
#
# Epoch 287/500
# --------------------
# train Loss: 0.0043 Img2Txt: 0.6592  Txt2Img: 0.6746
# test Loss: 0.0124 Img2Txt: 0.6592  Txt2Img: 0.6746
#
# Epoch 288/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6399  Txt2Img: 0.6677
# test Loss: 0.0123 Img2Txt: 0.6399  Txt2Img: 0.6677
#
# Epoch 289/500
# --------------------
# train Loss: 0.0043 Img2Txt: 0.6534  Txt2Img: 0.6722
# test Loss: 0.0123 Img2Txt: 0.6534  Txt2Img: 0.6722
#
# Epoch 290/500
# --------------------
# train Loss: 0.0041 Img2Txt: 0.6405  Txt2Img: 0.6792
# test Loss: 0.0124 Img2Txt: 0.6405  Txt2Img: 0.6792
#
# Epoch 291/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6712  Txt2Img: 0.6785
# test Loss: 0.0123 Img2Txt: 0.6712  Txt2Img: 0.6785
#
# Epoch 292/500
# --------------------
# train Loss: 0.0039 Img2Txt: 0.6372  Txt2Img: 0.6736
# test Loss: 0.0123 Img2Txt: 0.6372  Txt2Img: 0.6736
#
# Epoch 293/500
# --------------------
# train Loss: 0.0042 Img2Txt: 0.6572  Txt2Img: 0.6781
# test Loss: 0.0123 Img2Txt: 0.6572  Txt2Img: 0.6781
#
# Epoch 294/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6390  Txt2Img: 0.6717
# test Loss: 0.0124 Img2Txt: 0.6390  Txt2Img: 0.6717
#
# Epoch 295/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6683  Txt2Img: 0.6819
# test Loss: 0.0123 Img2Txt: 0.6683  Txt2Img: 0.6819
#
# Epoch 296/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6376  Txt2Img: 0.6736
# test Loss: 0.0124 Img2Txt: 0.6376  Txt2Img: 0.6736
#
# Epoch 297/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6657  Txt2Img: 0.6795
# test Loss: 0.0123 Img2Txt: 0.6657  Txt2Img: 0.6795
#
# Epoch 298/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6356  Txt2Img: 0.6691
# test Loss: 0.0125 Img2Txt: 0.6356  Txt2Img: 0.6691
#
# Epoch 299/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6626  Txt2Img: 0.6766
# test Loss: 0.0124 Img2Txt: 0.6626  Txt2Img: 0.6766
#
# Epoch 300/500
# --------------------
# train Loss: 0.0041 Img2Txt: 0.6391  Txt2Img: 0.6754
# test Loss: 0.0124 Img2Txt: 0.6391  Txt2Img: 0.6754
#
# Epoch 301/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6639  Txt2Img: 0.6741
# test Loss: 0.0123 Img2Txt: 0.6639  Txt2Img: 0.6741
#
# Epoch 302/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6302  Txt2Img: 0.6700
# test Loss: 0.0125 Img2Txt: 0.6302  Txt2Img: 0.6700
#
# Epoch 303/500
# --------------------
# train Loss: 0.0045 Img2Txt: 0.6640  Txt2Img: 0.6801
# test Loss: 0.0123 Img2Txt: 0.6640  Txt2Img: 0.6801
#
# Epoch 304/500
# --------------------
# train Loss: 0.0039 Img2Txt: 0.6409  Txt2Img: 0.6729
# test Loss: 0.0125 Img2Txt: 0.6409  Txt2Img: 0.6729
#
# Epoch 305/500
# --------------------
# train Loss: 0.0045 Img2Txt: 0.6548  Txt2Img: 0.6716
# test Loss: 0.0123 Img2Txt: 0.6548  Txt2Img: 0.6716
#
# Epoch 306/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6368  Txt2Img: 0.6719
# test Loss: 0.0125 Img2Txt: 0.6368  Txt2Img: 0.6719
#
# Epoch 307/500
# --------------------
# train Loss: 0.0045 Img2Txt: 0.6664  Txt2Img: 0.6778
# test Loss: 0.0121 Img2Txt: 0.6664  Txt2Img: 0.6778
#
# Epoch 308/500
# --------------------
# train Loss: 0.0037 Img2Txt: 0.6386  Txt2Img: 0.6691
# test Loss: 0.0123 Img2Txt: 0.6386  Txt2Img: 0.6691
#
# Epoch 309/500
# --------------------
# train Loss: 0.0042 Img2Txt: 0.6544  Txt2Img: 0.6778
# test Loss: 0.0121 Img2Txt: 0.6544  Txt2Img: 0.6778
#
# Epoch 310/500
# --------------------
# train Loss: 0.0037 Img2Txt: 0.6389  Txt2Img: 0.6668
# test Loss: 0.0125 Img2Txt: 0.6389  Txt2Img: 0.6668
#
# Epoch 311/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6644  Txt2Img: 0.6762
# test Loss: 0.0122 Img2Txt: 0.6644  Txt2Img: 0.6762
#
# Epoch 312/500
# --------------------
# train Loss: 0.0038 Img2Txt: 0.6353  Txt2Img: 0.6685
# test Loss: 0.0123 Img2Txt: 0.6353  Txt2Img: 0.6685
#
# Epoch 313/500
# --------------------
# train Loss: 0.0043 Img2Txt: 0.6549  Txt2Img: 0.6743
# test Loss: 0.0123 Img2Txt: 0.6549  Txt2Img: 0.6743
#
# Epoch 314/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6324  Txt2Img: 0.6669
# test Loss: 0.0124 Img2Txt: 0.6324  Txt2Img: 0.6669
#
# Epoch 315/500
# --------------------
# train Loss: 0.0043 Img2Txt: 0.6577  Txt2Img: 0.6809
# test Loss: 0.0123 Img2Txt: 0.6577  Txt2Img: 0.6809
#
# Epoch 316/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6325  Txt2Img: 0.6750
# test Loss: 0.0124 Img2Txt: 0.6325  Txt2Img: 0.6750
#
# Epoch 317/500
# --------------------
# train Loss: 0.0043 Img2Txt: 0.6649  Txt2Img: 0.6751
# test Loss: 0.0123 Img2Txt: 0.6649  Txt2Img: 0.6751
#
# Epoch 318/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6311  Txt2Img: 0.6609
# test Loss: 0.0124 Img2Txt: 0.6311  Txt2Img: 0.6609
#
# Epoch 319/500
# --------------------
# train Loss: 0.0042 Img2Txt: 0.6510  Txt2Img: 0.6813
# test Loss: 0.0123 Img2Txt: 0.6510  Txt2Img: 0.6813
#
# Epoch 320/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6310  Txt2Img: 0.6739
# test Loss: 0.0124 Img2Txt: 0.6310  Txt2Img: 0.6739
#
# Epoch 321/500
# --------------------
# train Loss: 0.0044 Img2Txt: 0.6567  Txt2Img: 0.6674
# test Loss: 0.0124 Img2Txt: 0.6567  Txt2Img: 0.6674
#
# Epoch 322/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6335  Txt2Img: 0.6659
# test Loss: 0.0124 Img2Txt: 0.6335  Txt2Img: 0.6659
#
# Epoch 323/500
# --------------------
# train Loss: 0.0043 Img2Txt: 0.6607  Txt2Img: 0.6836
# test Loss: 0.0122 Img2Txt: 0.6607  Txt2Img: 0.6836
#
# Epoch 324/500
# --------------------
# train Loss: 0.0039 Img2Txt: 0.6304  Txt2Img: 0.6623
# test Loss: 0.0125 Img2Txt: 0.6304  Txt2Img: 0.6623
#
# Epoch 325/500
# --------------------
# train Loss: 0.0043 Img2Txt: 0.6531  Txt2Img: 0.6711
# test Loss: 0.0124 Img2Txt: 0.6531  Txt2Img: 0.6711
#
# Epoch 326/500
# --------------------
# train Loss: 0.0039 Img2Txt: 0.6343  Txt2Img: 0.6721
# test Loss: 0.0124 Img2Txt: 0.6343  Txt2Img: 0.6721
#
# Epoch 327/500
# --------------------
# train Loss: 0.0043 Img2Txt: 0.6586  Txt2Img: 0.6752
# test Loss: 0.0123 Img2Txt: 0.6586  Txt2Img: 0.6752
#
# Epoch 328/500
# --------------------
# train Loss: 0.0038 Img2Txt: 0.6356  Txt2Img: 0.6642
# test Loss: 0.0124 Img2Txt: 0.6356  Txt2Img: 0.6642
#
# Epoch 329/500
# --------------------
# train Loss: 0.0043 Img2Txt: 0.6603  Txt2Img: 0.6745
# test Loss: 0.0122 Img2Txt: 0.6603  Txt2Img: 0.6745
#
# Epoch 330/500
# --------------------
# train Loss: 0.0038 Img2Txt: 0.6288  Txt2Img: 0.6712
# test Loss: 0.0123 Img2Txt: 0.6288  Txt2Img: 0.6712
#
# Epoch 331/500
# --------------------
# train Loss: 0.0041 Img2Txt: 0.6548  Txt2Img: 0.6694
# test Loss: 0.0123 Img2Txt: 0.6548  Txt2Img: 0.6694
#
# Epoch 332/500
# --------------------
# train Loss: 0.0038 Img2Txt: 0.6315  Txt2Img: 0.6602
# test Loss: 0.0124 Img2Txt: 0.6315  Txt2Img: 0.6602
#
# Epoch 333/500
# --------------------
# train Loss: 0.0042 Img2Txt: 0.6602  Txt2Img: 0.6772
# test Loss: 0.0123 Img2Txt: 0.6602  Txt2Img: 0.6772
#
# Epoch 334/500
# --------------------
# train Loss: 0.0038 Img2Txt: 0.6300  Txt2Img: 0.6738
# test Loss: 0.0123 Img2Txt: 0.6300  Txt2Img: 0.6738
#
# Epoch 335/500
# --------------------
# train Loss: 0.0041 Img2Txt: 0.6517  Txt2Img: 0.6665
# test Loss: 0.0124 Img2Txt: 0.6517  Txt2Img: 0.6665
#
# Epoch 336/500
# --------------------
# train Loss: 0.0039 Img2Txt: 0.6304  Txt2Img: 0.6648
# test Loss: 0.0123 Img2Txt: 0.6304  Txt2Img: 0.6648
#
# Epoch 337/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6596  Txt2Img: 0.6741
# test Loss: 0.0123 Img2Txt: 0.6596  Txt2Img: 0.6741
#
# Epoch 338/500
# --------------------
# train Loss: 0.0037 Img2Txt: 0.6254  Txt2Img: 0.6675
# test Loss: 0.0122 Img2Txt: 0.6254  Txt2Img: 0.6675
#
# Epoch 339/500
# --------------------
# train Loss: 0.0040 Img2Txt: 0.6509  Txt2Img: 0.6677
# test Loss: 0.0124 Img2Txt: 0.6509  Txt2Img: 0.6677
#
# Epoch 340/500
# --------------------
# train Loss: 0.0038 Img2Txt: 0.6337  Txt2Img: 0.6671
# test Loss: 0.0123 Img2Txt: 0.6337  Txt2Img: 0.6671
#
# Epoch 341/500
# --------------------
# train Loss: 0.0041 Img2Txt: 0.6583  Txt2Img: 0.6713
# test Loss: 0.0123 Img2Txt: 0.6583  Txt2Img: 0.6713
#
# Epoch 342/500
# --------------------
# train Loss: 0.0038 Img2Txt: 0.6296  Txt2Img: 0.6663
# test Loss: 0.0123 Img2Txt: 0.6296  Txt2Img: 0.6663
#
# Epoch 343/500
# --------------------
# train Loss: 0.0042 Img2Txt: 0.6603  Txt2Img: 0.6743
# test Loss: 0.0122 Img2Txt: 0.6603  Txt2Img: 0.6743
#
# Epoch 344/500
# --------------------
# train Loss: 0.0038 Img2Txt: 0.6311  Txt2Img: 0.6647
# test Loss: 0.0124 Img2Txt: 0.6311  Txt2Img: 0.6647
#
# Epoch 345/500
# --------------------
# train Loss: 0.0041 Img2Txt: 0.6538  Txt2Img: 0.6728
# test Loss: 0.0123 Img2Txt: 0.6538  Txt2Img: 0.6728
#
# Epoch 346/500
# --------------------
# ...
# test Loss: 0.0122 Img2Txt: 0.6526  Txt2Img: 0.6720
#
# Epoch 388/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6395  Txt2Img: 0.6647
# test Loss: 0.0123 Img2Txt: 0.6395  Txt2Img: 0.6647
#
# Epoch 389/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6479  Txt2Img: 0.6700
# test Loss: 0.0122 Img2Txt: 0.6479  Txt2Img: 0.6700
#
# Epoch 390/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6375  Txt2Img: 0.6658
# test Loss: 0.0123 Img2Txt: 0.6375  Txt2Img: 0.6658
#
# Epoch 391/500
# --------------------
# train Loss: 0.0037 Img2Txt: 0.6459  Txt2Img: 0.6694
# test Loss: 0.0123 Img2Txt: 0.6459  Txt2Img: 0.6694
#
# Epoch 392/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6399  Txt2Img: 0.6743
# test Loss: 0.0121 Img2Txt: 0.6399  Txt2Img: 0.6743
#
# Epoch 393/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6582  Txt2Img: 0.6750
# test Loss: 0.0121 Img2Txt: 0.6582  Txt2Img: 0.6750
#
# Epoch 394/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6393  Txt2Img: 0.6621
# test Loss: 0.0123 Img2Txt: 0.6393  Txt2Img: 0.6621
#
# Epoch 395/500
# --------------------
# train Loss: 0.0037 Img2Txt: 0.6465  Txt2Img: 0.6710
# test Loss: 0.0123 Img2Txt: 0.6465  Txt2Img: 0.6710
#
# Epoch 396/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6357  Txt2Img: 0.6710
# test Loss: 0.0122 Img2Txt: 0.6357  Txt2Img: 0.6710
#
# Epoch 397/500
# --------------------
# train Loss: 0.0037 Img2Txt: 0.6540  Txt2Img: 0.6732
# test Loss: 0.0122 Img2Txt: 0.6540  Txt2Img: 0.6732
#
# Epoch 398/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6383  Txt2Img: 0.6590
# test Loss: 0.0124 Img2Txt: 0.6383  Txt2Img: 0.6590
#
# Epoch 399/500
# --------------------
# train Loss: 0.0037 Img2Txt: 0.6493  Txt2Img: 0.6758
# test Loss: 0.0122 Img2Txt: 0.6493  Txt2Img: 0.6758
#
# Epoch 400/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6380  Txt2Img: 0.6716
# test Loss: 0.0122 Img2Txt: 0.6380  Txt2Img: 0.6716
#
# Epoch 401/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6463  Txt2Img: 0.6716
# test Loss: 0.0122 Img2Txt: 0.6463  Txt2Img: 0.6716
#
# Epoch 402/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6444  Txt2Img: 0.6707
# test Loss: 0.0123 Img2Txt: 0.6444  Txt2Img: 0.6707
#
# Epoch 403/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6568  Txt2Img: 0.6708
# test Loss: 0.0122 Img2Txt: 0.6568  Txt2Img: 0.6708
#
# Epoch 404/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6328  Txt2Img: 0.6650
# test Loss: 0.0123 Img2Txt: 0.6328  Txt2Img: 0.6650
#
# Epoch 405/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6460  Txt2Img: 0.6745
# test Loss: 0.0123 Img2Txt: 0.6460  Txt2Img: 0.6745
#
# Epoch 406/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6407  Txt2Img: 0.6713
# test Loss: 0.0123 Img2Txt: 0.6407  Txt2Img: 0.6713
#
# Epoch 407/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6460  Txt2Img: 0.6723
# test Loss: 0.0122 Img2Txt: 0.6460  Txt2Img: 0.6723
#
# Epoch 408/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6403  Txt2Img: 0.6670
# test Loss: 0.0123 Img2Txt: 0.6403  Txt2Img: 0.6670
#
# Epoch 409/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6492  Txt2Img: 0.6700
# test Loss: 0.0123 Img2Txt: 0.6492  Txt2Img: 0.6700
#
# Epoch 410/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6395  Txt2Img: 0.6666
# test Loss: 0.0123 Img2Txt: 0.6395  Txt2Img: 0.6666
#
# Epoch 411/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6365  Txt2Img: 0.6670
# test Loss: 0.0123 Img2Txt: 0.6365  Txt2Img: 0.6670
#
# Epoch 412/500
# --------------------
# train Loss: 0.0037 Img2Txt: 0.6440  Txt2Img: 0.6631
# test Loss: 0.0123 Img2Txt: 0.6440  Txt2Img: 0.6631
#
# Epoch 413/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6495  Txt2Img: 0.6734
# test Loss: 0.0123 Img2Txt: 0.6495  Txt2Img: 0.6734
#
# Epoch 414/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6384  Txt2Img: 0.6661
# test Loss: 0.0121 Img2Txt: 0.6384  Txt2Img: 0.6661
#
# Epoch 415/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6444  Txt2Img: 0.6695
# test Loss: 0.0122 Img2Txt: 0.6444  Txt2Img: 0.6695
#
# Epoch 416/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6408  Txt2Img: 0.6601
# test Loss: 0.0124 Img2Txt: 0.6408  Txt2Img: 0.6601
#
# Epoch 417/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6429  Txt2Img: 0.6702
# test Loss: 0.0123 Img2Txt: 0.6429  Txt2Img: 0.6702
#
# Epoch 418/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6372  Txt2Img: 0.6689
# test Loss: 0.0122 Img2Txt: 0.6372  Txt2Img: 0.6689
#
# Epoch 419/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6522  Txt2Img: 0.6711
# test Loss: 0.0122 Img2Txt: 0.6522  Txt2Img: 0.6711
#
# Epoch 420/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6365  Txt2Img: 0.6619
# test Loss: 0.0123 Img2Txt: 0.6365  Txt2Img: 0.6619
#
# Epoch 421/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6487  Txt2Img: 0.6675
# test Loss: 0.0124 Img2Txt: 0.6487  Txt2Img: 0.6675
#
# Epoch 422/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6354  Txt2Img: 0.6715
# test Loss: 0.0122 Img2Txt: 0.6354  Txt2Img: 0.6715
#
# Epoch 423/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6507  Txt2Img: 0.6651
# test Loss: 0.0123 Img2Txt: 0.6507  Txt2Img: 0.6651
#
# Epoch 424/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6422  Txt2Img: 0.6625
# test Loss: 0.0122 Img2Txt: 0.6422  Txt2Img: 0.6625
#
# Epoch 425/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6521  Txt2Img: 0.6732
# test Loss: 0.0123 Img2Txt: 0.6521  Txt2Img: 0.6732
#
# Epoch 426/500
# --------------------
# train Loss: 0.0037 Img2Txt: 0.6425  Txt2Img: 0.6550
# test Loss: 0.0124 Img2Txt: 0.6425  Txt2Img: 0.6550
#
# Epoch 427/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6413  Txt2Img: 0.6683
# test Loss: 0.0122 Img2Txt: 0.6413  Txt2Img: 0.6683
#
# Epoch 428/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6426  Txt2Img: 0.6604
# test Loss: 0.0122 Img2Txt: 0.6426  Txt2Img: 0.6604
#
# Epoch 429/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6492  Txt2Img: 0.6769
# test Loss: 0.0122 Img2Txt: 0.6492  Txt2Img: 0.6769
#
# Epoch 430/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6383  Txt2Img: 0.6595
# test Loss: 0.0123 Img2Txt: 0.6383  Txt2Img: 0.6595
#
# Epoch 431/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6456  Txt2Img: 0.6746
# test Loss: 0.0122 Img2Txt: 0.6456  Txt2Img: 0.6746
#
# Epoch 432/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6394  Txt2Img: 0.6621
# test Loss: 0.0122 Img2Txt: 0.6394  Txt2Img: 0.6621
#
# Epoch 433/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6535  Txt2Img: 0.6725
# test Loss: 0.0123 Img2Txt: 0.6535  Txt2Img: 0.6725
#
# Epoch 434/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6347  Txt2Img: 0.6641
# test Loss: 0.0122 Img2Txt: 0.6347  Txt2Img: 0.6641
#
# Epoch 435/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6568  Txt2Img: 0.6718
# test Loss: 0.0122 Img2Txt: 0.6568  Txt2Img: 0.6718
#
# Epoch 436/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6437  Txt2Img: 0.6646
# test Loss: 0.0122 Img2Txt: 0.6437  Txt2Img: 0.6646
#
# Epoch 437/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6459  Txt2Img: 0.6690
# test Loss: 0.0123 Img2Txt: 0.6459  Txt2Img: 0.6690
#
# Epoch 438/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6374  Txt2Img: 0.6593
# test Loss: 0.0122 Img2Txt: 0.6374  Txt2Img: 0.6593
#
# Epoch 439/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6536  Txt2Img: 0.6739
# test Loss: 0.0122 Img2Txt: 0.6536  Txt2Img: 0.6739
#
# Epoch 440/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6392  Txt2Img: 0.6568
# test Loss: 0.0122 Img2Txt: 0.6392  Txt2Img: 0.6568
#
# Epoch 441/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6414  Txt2Img: 0.6754
# test Loss: 0.0122 Img2Txt: 0.6414  Txt2Img: 0.6754
#
# Epoch 442/500
# --------------------
# train Loss: 0.0036 Img2Txt: 0.6404  Txt2Img: 0.6544
# test Loss: 0.0123 Img2Txt: 0.6404  Txt2Img: 0.6544
#
# Epoch 443/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6543  Txt2Img: 0.6707
# test Loss: 0.0124 Img2Txt: 0.6543  Txt2Img: 0.6707
#
# Epoch 444/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6395  Txt2Img: 0.6600
# test Loss: 0.0121 Img2Txt: 0.6395  Txt2Img: 0.6600
#
# Epoch 445/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6560  Txt2Img: 0.6747
# test Loss: 0.0122 Img2Txt: 0.6560  Txt2Img: 0.6747
#
# Epoch 446/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6430  Txt2Img: 0.6613
# test Loss: 0.0122 Img2Txt: 0.6430  Txt2Img: 0.6613
#
# Epoch 447/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6536  Txt2Img: 0.6695
# test Loss: 0.0123 Img2Txt: 0.6536  Txt2Img: 0.6695
#
# Epoch 448/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6383  Txt2Img: 0.6640
# test Loss: 0.0121 Img2Txt: 0.6383  Txt2Img: 0.6640
#
# Epoch 449/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6552  Txt2Img: 0.6649
# test Loss: 0.0123 Img2Txt: 0.6552  Txt2Img: 0.6649
#
# Epoch 450/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6367  Txt2Img: 0.6614
# test Loss: 0.0122 Img2Txt: 0.6367  Txt2Img: 0.6614
#
# Epoch 451/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6561  Txt2Img: 0.6760
# test Loss: 0.0122 Img2Txt: 0.6561  Txt2Img: 0.6760
#
# Epoch 452/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6326  Txt2Img: 0.6624
# test Loss: 0.0121 Img2Txt: 0.6326  Txt2Img: 0.6624
#
# Epoch 453/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6504  Txt2Img: 0.6642
# test Loss: 0.0123 Img2Txt: 0.6504  Txt2Img: 0.6642
#
# Epoch 454/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6386  Txt2Img: 0.6557
# test Loss: 0.0122 Img2Txt: 0.6386  Txt2Img: 0.6557
#
# Epoch 455/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6552  Txt2Img: 0.6725
# test Loss: 0.0122 Img2Txt: 0.6552  Txt2Img: 0.6725
#
# Epoch 456/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6301  Txt2Img: 0.6641
# test Loss: 0.0121 Img2Txt: 0.6301  Txt2Img: 0.6641
#
# Epoch 457/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6546  Txt2Img: 0.6692
# test Loss: 0.0123 Img2Txt: 0.6546  Txt2Img: 0.6692
#
# Epoch 458/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6394  Txt2Img: 0.6618
# test Loss: 0.0122 Img2Txt: 0.6394  Txt2Img: 0.6618
#
# Epoch 459/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6502  Txt2Img: 0.6702
# test Loss: 0.0122 Img2Txt: 0.6502  Txt2Img: 0.6702
#
# Epoch 460/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6350  Txt2Img: 0.6621
# test Loss: 0.0121 Img2Txt: 0.6350  Txt2Img: 0.6621
#
# Epoch 461/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6527  Txt2Img: 0.6620
# test Loss: 0.0123 Img2Txt: 0.6527  Txt2Img: 0.6620
#
# Epoch 462/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6343  Txt2Img: 0.6577
# test Loss: 0.0121 Img2Txt: 0.6343  Txt2Img: 0.6577
#
# Epoch 463/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6516  Txt2Img: 0.6734
# test Loss: 0.0122 Img2Txt: 0.6516  Txt2Img: 0.6734
#
# Epoch 464/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6318  Txt2Img: 0.6601
# test Loss: 0.0121 Img2Txt: 0.6318  Txt2Img: 0.6601
#
# Epoch 465/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6487  Txt2Img: 0.6607
# test Loss: 0.0124 Img2Txt: 0.6487  Txt2Img: 0.6607
#
# Epoch 466/500
# --------------------
# train Loss: 0.0035 Img2Txt: 0.6315  Txt2Img: 0.6594
# test Loss: 0.0121 Img2Txt: 0.6315  Txt2Img: 0.6594
#
# Epoch 467/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6542  Txt2Img: 0.6738
# test Loss: 0.0122 Img2Txt: 0.6542  Txt2Img: 0.6738
#
# Epoch 468/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6400  Txt2Img: 0.6591
# test Loss: 0.0122 Img2Txt: 0.6400  Txt2Img: 0.6591
#
# Epoch 469/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6408  Txt2Img: 0.6683
# test Loss: 0.0122 Img2Txt: 0.6408  Txt2Img: 0.6683
#
# Epoch 470/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6429  Txt2Img: 0.6637
# test Loss: 0.0121 Img2Txt: 0.6429  Txt2Img: 0.6637
#
# Epoch 471/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6431  Txt2Img: 0.6698
# test Loss: 0.0121 Img2Txt: 0.6431  Txt2Img: 0.6698
#
# Epoch 472/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6413  Txt2Img: 0.6582
# test Loss: 0.0122 Img2Txt: 0.6413  Txt2Img: 0.6582
#
# Epoch 473/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6472  Txt2Img: 0.6711
# test Loss: 0.0122 Img2Txt: 0.6472  Txt2Img: 0.6711
#
# Epoch 474/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6363  Txt2Img: 0.6663
# test Loss: 0.0122 Img2Txt: 0.6363  Txt2Img: 0.6663
#
# Epoch 475/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6448  Txt2Img: 0.6686
# test Loss: 0.0121 Img2Txt: 0.6448  Txt2Img: 0.6686
#
# Epoch 476/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6396  Txt2Img: 0.6597
# test Loss: 0.0122 Img2Txt: 0.6396  Txt2Img: 0.6597
#
# Epoch 477/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6505  Txt2Img: 0.6697
# test Loss: 0.0121 Img2Txt: 0.6505  Txt2Img: 0.6697
#
# Epoch 478/500
# --------------------
# train Loss: 0.0031 Img2Txt: 0.6354  Txt2Img: 0.6572
# test Loss: 0.0122 Img2Txt: 0.6354  Txt2Img: 0.6572
#
# Epoch 479/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6384  Txt2Img: 0.6648
# test Loss: 0.0121 Img2Txt: 0.6384  Txt2Img: 0.6648
#
# Epoch 480/500
# --------------------
# train Loss: 0.0031 Img2Txt: 0.6460  Txt2Img: 0.6614
# test Loss: 0.0123 Img2Txt: 0.6460  Txt2Img: 0.6614
#
# Epoch 481/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6425  Txt2Img: 0.6723
# test Loss: 0.0121 Img2Txt: 0.6425  Txt2Img: 0.6723
#
# Epoch 482/500
# --------------------
# train Loss: 0.0031 Img2Txt: 0.6396  Txt2Img: 0.6648
# test Loss: 0.0121 Img2Txt: 0.6396  Txt2Img: 0.6648
#
# Epoch 483/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6399  Txt2Img: 0.6669
# test Loss: 0.0121 Img2Txt: 0.6399  Txt2Img: 0.6669
#
# Epoch 484/500
# --------------------
# train Loss: 0.0031 Img2Txt: 0.6427  Txt2Img: 0.6658
# test Loss: 0.0123 Img2Txt: 0.6427  Txt2Img: 0.6658
#
# Epoch 485/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6456  Txt2Img: 0.6723
# test Loss: 0.0121 Img2Txt: 0.6456  Txt2Img: 0.6723
#
# Epoch 486/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6321  Txt2Img: 0.6628
# test Loss: 0.0122 Img2Txt: 0.6321  Txt2Img: 0.6628
#
# Epoch 487/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6462  Txt2Img: 0.6646
# test Loss: 0.0122 Img2Txt: 0.6462  Txt2Img: 0.6646
#
# Epoch 488/500
# --------------------
# train Loss: 0.0031 Img2Txt: 0.6388  Txt2Img: 0.6588
# test Loss: 0.0123 Img2Txt: 0.6388  Txt2Img: 0.6588
#
# Epoch 489/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6413  Txt2Img: 0.6682
# test Loss: 0.0121 Img2Txt: 0.6413  Txt2Img: 0.6682
#
# Epoch 490/500
# --------------------
# train Loss: 0.0031 Img2Txt: 0.6399  Txt2Img: 0.6676
# test Loss: 0.0122 Img2Txt: 0.6399  Txt2Img: 0.6676
#
# Epoch 491/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6435  Txt2Img: 0.6665
# test Loss: 0.0122 Img2Txt: 0.6435  Txt2Img: 0.6665
#
# Epoch 492/500
# --------------------
# train Loss: 0.0032 Img2Txt: 0.6399  Txt2Img: 0.6698
# test Loss: 0.0122 Img2Txt: 0.6399  Txt2Img: 0.6698
#
# Epoch 493/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6434  Txt2Img: 0.6663
# test Loss: 0.0121 Img2Txt: 0.6434  Txt2Img: 0.6663
#
# Epoch 494/500
# --------------------
# train Loss: 0.0031 Img2Txt: 0.6415  Txt2Img: 0.6697
# test Loss: 0.0122 Img2Txt: 0.6415  Txt2Img: 0.6697
#
# Epoch 495/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6387  Txt2Img: 0.6643
# test Loss: 0.0123 Img2Txt: 0.6387  Txt2Img: 0.6643
#
# Epoch 496/500
# --------------------
# train Loss: 0.0031 Img2Txt: 0.6394  Txt2Img: 0.6691
# test Loss: 0.0122 Img2Txt: 0.6394  Txt2Img: 0.6691
#
# Epoch 497/500
# --------------------
# train Loss: 0.0033 Img2Txt: 0.6466  Txt2Img: 0.6697
# test Loss: 0.0120 Img2Txt: 0.6466  Txt2Img: 0.6697
#
# Epoch 498/500
# --------------------
# train Loss: 0.0031 Img2Txt: 0.6385  Txt2Img: 0.6582
# test Loss: 0.0123 Img2Txt: 0.6385  Txt2Img: 0.6582
#
# Epoch 499/500
# --------------------
# train Loss: 0.0034 Img2Txt: 0.6421  Txt2Img: 0.6692
# test Loss: 0.0121 Img2Txt: 0.6421  Txt2Img: 0.6692
#
# Epoch 500/500
# --------------------
# train Loss: 0.0031 Img2Txt: 0.6422  Txt2Img: 0.6690
# test Loss: 0.0122 Img2Txt: 0.6422  Txt2Img: 0.6690
#
# Training complete in 1m 38s
# Best average ACC: 0.702351
# ...Training is completed...
# ...Evaluation on testing data...
# ...Image to Text MAP = 0.6947012621304236
# ...Text to Image MAP = 0.7100000824457635
# ...Average MAP = 0.7023506722880936
